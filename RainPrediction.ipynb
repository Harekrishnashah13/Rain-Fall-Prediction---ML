# %%
# !pip install catboost



import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
import scipy.stats as stats
from sklearn.model_selection import train_test_split
from collections import Counter
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
import joblib
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp311-cp311-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.55.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp311-cp311-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 8.5 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7

# %%
import kagglehub

df = pd.read_csv("/weatherAUS.csv")
pd.set_option("display.max_columns", None)
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am WindDir3pm  \
# 0            NaN           W           44.0          W        WNW
# 1            NaN         WNW           44.0        NNW        WSW
# 2            NaN         WSW           46.0          W        WSW
# 3            NaN          NE           24.0         SE          E
# 4            NaN           W           41.0        ENE         NW
# ...          ...         ...            ...        ...        ...
# 145455       NaN           E           31.0         SE        ENE
# 145456       NaN         NNW           22.0         SE          N
# 145457       NaN           N           37.0         SE        WNW
# 145458       NaN          SE           28.0        SSE          N
# 145459       NaN         NaN            NaN        ESE        ESE
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0               20.0          24.0         71.0         22.0       1007.7
# 1                4.0          22.0         44.0         25.0       1010.6
# 2               19.0          26.0         38.0         30.0       1007.6
# 3               11.0           9.0         45.0         16.0       1017.6
# 4                7.0          20.0         82.0         33.0       1010.8
# ...              ...           ...          ...          ...          ...
# 145455          13.0          11.0         51.0         24.0       1024.6
# 145456          13.0           9.0         56.0         21.0       1023.5
# 145457           9.0           9.0         53.0         24.0       1021.0
# 145458          13.0           7.0         51.0         24.0       1019.4
# 145459          17.0          17.0         62.0         36.0       1020.2
#
#         Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm RainToday  \
# 0            1007.1       8.0       NaN     16.9     21.8        No
# 1            1007.8       NaN       NaN     17.2     24.3        No
# 2            1008.7       NaN       2.0     21.0     23.2        No
# 3            1012.8       NaN       NaN     18.1     26.5        No
# 4            1006.0       7.0       8.0     17.8     29.7        No
# ...             ...       ...       ...      ...      ...       ...
# 145455       1020.3       NaN       NaN     10.1     22.4        No
# 145456       1019.1       NaN       NaN     10.9     24.5        No
# 145457       1016.8       NaN       NaN     12.5     26.1        No
# 145458       1016.5       3.0       2.0     15.1     26.0        No
# 145459       1017.9       8.0       8.0     15.0     20.9        No
#
#        RainTomorrow
# 0                No
# 1                No
# 2                No
# 3                No
# 4                No
# ...             ...
# 145455           No
# 145456           No
# 145457           No
# 145458           No
# 145459          NaN
#
# [145460 rows x 23 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
numerical_feature = [feature for feature in df.columns if df[feature].dtypes != 'O']
discrete_feature=[feature for feature in numerical_feature if len(df[feature].unique())<25]
continuous_feature = [feature for feature in numerical_feature if feature not in discrete_feature]
categorical_feature = [feature for feature in df.columns if feature not in numerical_feature]
print("Numerical Features Count {}".format(len(numerical_feature)))
print("Discrete feature Count {}".format(len(discrete_feature)))
print("Continuous feature Count {}".format(len(continuous_feature)))
print("Categorical feature Count {}".format(len(categorical_feature)))
# Out:
# Numerical Features Count 16
# Discrete feature Count 2
# Continuous feature Count 14
# Categorical feature Count 7

# %%
# Handle Missing Values
df.isnull().sum()*100/len(df)
# Out:
# Date              0.000000
# Location          0.000000
# MinTemp           1.020899
# MaxTemp           0.866905
# Rainfall          2.241853
# Evaporation      43.166506
# Sunshine         48.009762
# WindGustDir       7.098859
# WindGustSpeed     7.055548
# WindDir9am        7.263853
# WindDir3pm        2.906641
# WindSpeed9am      1.214767
# WindSpeed3pm      2.105046
# Humidity9am       1.824557
# Humidity3pm       3.098446
# Pressure9am      10.356799
# Pressure3pm      10.331363
# Cloud9am         38.421559
# Cloud3pm         40.807095
# Temp9am           1.214767
# Temp3pm           2.481094
# RainToday         2.241853
# RainTomorrow      2.245978
# dtype: float64

# %%
print(numerical_feature)
# Out:
# ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm']

# %%
def randomsampleimputation(df, variable):
    df[variable]=df[variable]
    random_sample=df[variable].dropna().sample(df[variable].isnull().sum(),random_state=0)
    random_sample.index=df[df[variable].isnull()].index
    df.loc[df[variable].isnull(),variable]=random_sample

# %%
randomsampleimputation(df, "Cloud9am")
randomsampleimputation(df, "Cloud3pm")
randomsampleimputation(df, "Evaporation")
randomsampleimputation(df, "Sunshine")

# %%
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          2.4
# 1       2008-12-02   Albury      7.4     25.1       0.0          3.6
# 2       2008-12-03   Albury     12.9     25.7       0.0          2.6
# 3       2008-12-04   Albury      9.2     28.0       0.0         18.4
# 4       2008-12-05   Albury     17.5     32.3       1.0          5.4
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          1.4
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          7.6
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          6.8
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          2.6
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          1.4
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am WindDir3pm  \
# 0            8.3           W           44.0          W        WNW
# 1           10.0         WNW           44.0        NNW        WSW
# 2            4.4         WSW           46.0          W        WSW
# 3            8.9          NE           24.0         SE          E
# 4            3.0           W           41.0        ENE         NW
# ...          ...         ...            ...        ...        ...
# 145455       7.8           E           31.0         SE        ENE
# 145456      13.5         NNW           22.0         SE          N
# 145457      11.0           N           37.0         SE        WNW
# 145458      13.2          SE           28.0        SSE          N
# 145459       0.7         NaN            NaN        ESE        ESE
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0               20.0          24.0         71.0         22.0       1007.7
# 1                4.0          22.0         44.0         25.0       1010.6
# 2               19.0          26.0         38.0         30.0       1007.6
# 3               11.0           9.0         45.0         16.0       1017.6
# 4                7.0          20.0         82.0         33.0       1010.8
# ...              ...           ...          ...          ...          ...
# 145455          13.0          11.0         51.0         24.0       1024.6
# 145456          13.0           9.0         56.0         21.0       1023.5
# 145457           9.0           9.0         53.0         24.0       1021.0
# 145458          13.0           7.0         51.0         24.0       1019.4
# 145459          17.0          17.0         62.0         36.0       1020.2
#
#         Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm RainToday  \
# 0            1007.1       8.0       0.0     16.9     21.8        No
# 1            1007.8       7.0       1.0     17.2     24.3        No
# 2            1008.7       8.0       2.0     21.0     23.2        No
# 3            1012.8       0.0       5.0     18.1     26.5        No
# 4            1006.0       7.0       8.0     17.8     29.7        No
# ...             ...       ...       ...      ...      ...       ...
# 145455       1020.3       1.0       1.0     10.1     22.4        No
# 145456       1019.1       8.0       5.0     10.9     24.5        No
# 145457       1016.8       8.0       1.0     12.5     26.1        No
# 145458       1016.5       3.0       2.0     15.1     26.0        No
# 145459       1017.9       8.0       8.0     15.0     20.9        No
#
#        RainTomorrow
# 0                No
# 1                No
# 2                No
# 3                No
# 4                No
# ...             ...
# 145455           No
# 145456           No
# 145457           No
# 145458           No
# 145459          NaN
#
# [145460 rows x 23 columns]

# %%
print(df.dtypes)
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %%
corrmat = df.select_dtypes(include=['number']).corr(method="spearman")

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20,20))
sns.heatmap(corrmat, annot=True, cmap="coolwarm")
plt.show()

# %%
for feature in continuous_feature:
    data=df.copy()
    sns.distplot(df[feature])
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.figure(figsize=(15,15))
    plt.show()
# Out:
# <ipython-input-15-f3f36df57cc9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# <ipython-input-15-f3f36df57cc9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# <ipython-input-15-f3f36df57cc9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# <ipython-input-15-f3f36df57cc9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# <ipython-input-15-f3f36df57cc9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# <ipython-input-15-f3f36df57cc9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# <ipython-input-15-f3f36df57cc9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# <ipython-input-15-f3f36df57cc9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# <ipython-input-15-f3f36df57cc9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# <ipython-input-15-f3f36df57cc9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# <ipython-input-15-f3f36df57cc9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# <ipython-input-15-f3f36df57cc9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# <ipython-input-15-f3f36df57cc9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])
# <ipython-input-15-f3f36df57cc9>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[feature])

# %%
#A for loop is used to plot a boxplot for all the continuous features to see the outliers
for feature in continuous_feature:
    data=df.copy()
    sns.boxplot(data[feature])
    plt.title(feature)
    plt.figure(figsize=(10,10))

# %%
for feature in continuous_feature:
    if(df[feature].isnull().sum()*100/len(df))>0:
        df[feature] = df[feature].fillna(df[feature].median())

# %%
df.isnull().sum()*100/len(df)
# Out:
# Date             0.000000
# Location         0.000000
# MinTemp          0.000000
# MaxTemp          0.000000
# Rainfall         0.000000
# Evaporation      0.000000
# Sunshine         0.000000
# WindGustDir      7.098859
# WindGustSpeed    0.000000
# WindDir9am       7.263853
# WindDir3pm       2.906641
# WindSpeed9am     0.000000
# WindSpeed3pm     0.000000
# Humidity9am      0.000000
# Humidity3pm      0.000000
# Pressure9am      0.000000
# Pressure3pm      0.000000
# Cloud9am         0.000000
# Cloud3pm         0.000000
# Temp9am          0.000000
# Temp3pm          0.000000
# RainToday        2.241853
# RainTomorrow     2.245978
# dtype: float64

# %%
discrete_feature
# Out:
# ['Cloud9am', 'Cloud3pm']

# %%
def mode_nan(df,variable):
    mode=df[variable].value_counts().index[0]
    df[variable].fillna(mode,inplace=True)
mode_nan(df,"Cloud9am")
mode_nan(df,"Cloud3pm")
# Out:
# <ipython-input-21-582ec046471a>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[variable].fillna(mode,inplace=True)

# %%
df["RainToday"] = pd.get_dummies(df["RainToday"], drop_first = True)
df["RainTomorrow"] = pd.get_dummies(df["RainTomorrow"], drop_first = True)
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          2.4
# 1       2008-12-02   Albury      7.4     25.1       0.0          3.6
# 2       2008-12-03   Albury     12.9     25.7       0.0          2.6
# 3       2008-12-04   Albury      9.2     28.0       0.0         18.4
# 4       2008-12-05   Albury     17.5     32.3       1.0          5.4
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          1.4
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          7.6
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          6.8
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          2.6
# 145459  2017-06-25    Uluru     14.9     22.6       0.0          1.4
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am WindDir3pm  \
# 0            8.3           W           44.0          W        WNW
# 1           10.0         WNW           44.0        NNW        WSW
# 2            4.4         WSW           46.0          W        WSW
# 3            8.9          NE           24.0         SE          E
# 4            3.0           W           41.0        ENE         NW
# ...          ...         ...            ...        ...        ...
# 145455       7.8           E           31.0         SE        ENE
# 145456      13.5         NNW           22.0         SE          N
# 145457      11.0           N           37.0         SE        WNW
# 145458      13.2          SE           28.0        SSE          N
# 145459       0.7         NaN           39.0        ESE        ESE
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0               20.0          24.0         71.0         22.0       1007.7
# 1                4.0          22.0         44.0         25.0       1010.6
# 2               19.0          26.0         38.0         30.0       1007.6
# 3               11.0           9.0         45.0         16.0       1017.6
# 4                7.0          20.0         82.0         33.0       1010.8
# ...              ...           ...          ...          ...          ...
# 145455          13.0          11.0         51.0         24.0       1024.6
# 145456          13.0           9.0         56.0         21.0       1023.5
# 145457           9.0           9.0         53.0         24.0       1021.0
# 145458          13.0           7.0         51.0         24.0       1019.4
# 145459          17.0          17.0         62.0         36.0       1020.2
#
#         Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0            1007.1       8.0       0.0     16.9     21.8      False
# 1            1007.8       7.0       1.0     17.2     24.3      False
# 2            1008.7       8.0       2.0     21.0     23.2      False
# 3            1012.8       0.0       5.0     18.1     26.5      False
# 4            1006.0       7.0       8.0     17.8     29.7      False
# ...             ...       ...       ...      ...      ...        ...
# 145455       1020.3       1.0       1.0     10.1     22.4      False
# 145456       1019.1       8.0       5.0     10.9     24.5      False
# 145457       1016.8       8.0       1.0     12.5     26.1      False
# 145458       1016.5       3.0       2.0     15.1     26.0      False
# 145459       1017.9       8.0       8.0     15.0     20.9      False
#
#         RainTomorrow
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ...              ...
# 145455         False
# 145456         False
# 145457         False
# 145458         False
# 145459         False
#
# [145460 rows x 23 columns]

# %%
for feature in categorical_feature:
    print(feature, (df.groupby([feature])["RainTomorrow"].mean().sort_values(ascending = False)).index)
# Out:
# Date Index(['2008-02-03', '2008-01-12', '2008-01-16', '2008-02-04', '2008-01-30',
#        '2007-12-01', '2007-12-03', '2007-12-24', '2007-11-04', '2007-11-17',
#        ...
#        '2007-11-21', '2008-01-15', '2008-01-17', '2008-01-20', '2008-03-12',
#        '2008-03-13', '2008-01-10', '2008-01-11', '2008-03-03', '2008-03-04'],
#       dtype='object', name='Date', length=3436)
# Location Index(['Portland', 'Walpole', 'Cairns', 'Dartmoor', 'NorfolkIsland',
#        'MountGambier', 'Albany', 'Witchcliffe', 'CoffsHarbour', 'MountGinini',
#        'NorahHead', 'Darwin', 'Sydney', 'SydneyAirport', 'Ballarat',
#        'GoldCoast', 'Watsonia', 'Newcastle', 'Hobart', 'Wollongong',
#        'Williamtown', 'Launceston', 'Brisbane', 'MelbourneAirport', 'Adelaide',
#        'Sale', 'Albury', 'Perth', 'Melbourne', 'Nuriootpa', 'Penrith',
#        'BadgerysCreek', 'PerthAirport', 'Tuggeranong', 'Richmond', 'Bendigo',
#        'Canberra', 'WaggaWagga', 'Townsville', 'Katherine', 'PearceRAAF',
#        'SalmonGums', 'Nhil', 'Moree', 'Cobar', 'Mildura', 'AliceSprings',
#        'Uluru', 'Woomera'],
#       dtype='object', name='Location')
# WindGustDir Index(['NNW', 'NW', 'WNW', 'N', 'W', 'WSW', 'NNE', 'S', 'SSW', 'SW', 'SSE',
#        'NE', 'SE', 'ESE', 'ENE', 'E'],
#       dtype='object', name='WindGustDir')
# WindDir9am Index(['NNW', 'N', 'NW', 'NNE', 'WNW', 'W', 'WSW', 'SW', 'SSW', 'NE', 'S',
#        'SSE', 'ENE', 'SE', 'ESE', 'E'],
#       dtype='object', name='WindDir9am')
# WindDir3pm Index(['NW', 'NNW', 'N', 'WNW', 'W', 'NNE', 'WSW', 'SSW', 'S', 'SW', 'SE',
#        'NE', 'SSE', 'ENE', 'E', 'ESE'],
#       dtype='object', name='WindDir3pm')
# RainToday Index([True, False], dtype='bool', name='RainToday')
# RainTomorrow Index([True, False], dtype='bool', name='RainTomorrow')

# %%
windgustdir = {'NNW':0, 'NW':1, 'WNW':2, 'N':3, 'W':4, 'WSW':5, 'NNE':6, 'S':7, 'SSW':8, 'SW':9, 'SSE':10,
       'NE':11, 'SE':12, 'ESE':13, 'ENE':14, 'E':15}
winddir9am = {'NNW':0, 'N':1, 'NW':2, 'NNE':3, 'WNW':4, 'W':5, 'WSW':6, 'SW':7, 'SSW':8, 'NE':9, 'S':10,
       'SSE':11, 'ENE':12, 'SE':13, 'ESE':14, 'E':15}
winddir3pm = {'NW':0, 'NNW':1, 'N':2, 'WNW':3, 'W':4, 'NNE':5, 'WSW':6, 'SSW':7, 'S':8, 'SW':9, 'SE':10,
       'NE':11, 'SSE':12, 'ENE':13, 'E':14, 'ESE':15}
df["WindGustDir"] = df["WindGustDir"].map(windgustdir)
df["WindDir9am"] = df["WindDir9am"].map(winddir9am)
df["WindDir3pm"] = df["WindDir3pm"].map(winddir3pm)

# %%
df["WindGustDir"] = df["WindGustDir"].fillna(df["WindGustDir"].value_counts().index[0])
df["WindDir9am"] = df["WindDir9am"].fillna(df["WindDir9am"].value_counts().index[0])
df["WindDir3pm"] = df["WindDir3pm"].fillna(df["WindDir3pm"].value_counts().index[0])

# %%
df.isnull().sum()*100/len(df)
# Out:
# Date             0.0
# Location         0.0
# MinTemp          0.0
# MaxTemp          0.0
# Rainfall         0.0
# Evaporation      0.0
# Sunshine         0.0
# WindGustDir      0.0
# WindGustSpeed    0.0
# WindDir9am       0.0
# WindDir3pm       0.0
# WindSpeed9am     0.0
# WindSpeed3pm     0.0
# Humidity9am      0.0
# Humidity3pm      0.0
# Pressure9am      0.0
# Pressure3pm      0.0
# Cloud9am         0.0
# Cloud3pm         0.0
# Temp9am          0.0
# Temp3pm          0.0
# RainToday        0.0
# RainTomorrow     0.0
# dtype: float64

# %%
df1 = df.groupby(["Location"])["RainTomorrow"].value_counts().sort_values().unstack()

# %%
df1
# Out:
# RainTomorrow      False  True
# Location
# Adelaide           2505    688
# Albany             2138    902
# Albury             2422    618
# AliceSprings       2796    244
# BadgerysCreek      2426    583
# Ballarat           2259    781
# Bendigo            2478    562
# Brisbane           2484    709
# Cairns             2090    950
# Canberra           2807    629
# Cobar              2623    386
# CoffsHarbour       2140    869
# Dartmoor           2087    922
# Darwin             2341    852
# GoldCoast          2265    775
# Hobart             2432    761
# Katherine          1313    265
# Launceston         2341    699
# Melbourne          2557    636
# MelbourneAirport   2356    653
# Mildura            2682    327
# Moree              2615    394
# MountGambier       2120    920
# MountGinini        2221    819
# Newcastle          2308    731
# Nhil               1336    242
# NorahHead          2196    808
# NorfolkIsland      2090    919
# Nuriootpa          2417    592
# PearceRAAF         2504    505
# Penrith            2444    595
# Perth              2548    645
# PerthAirport       2442    567
# Portland           1914   1095
# Richmond           2449    560
# Sale               2366    643
# SalmonGums         2529    472
# Sydney             2479    865
# SydneyAirport      2235    774
# Townsville         2521    519
# Tuggeranong        2471    568
# Uluru              1462    116
# WaggaWagga         2473    536
# Walpole            2057    949
# Watsonia           2271    738
# Williamtown        2309    700
# Witchcliffe        2130    879
# Wollongong         2327    713
# Woomera            2807    202

# %%
print(df.columns)
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
df1.iloc[:, 1].sort_values(ascending=False)

  # Corrected sorting for second column
# Out:
# Location
# Portland            1095
# Cairns               950
# Walpole              949
# Dartmoor             922
# MountGambier         920
# NorfolkIsland        919
# Albany               902
# Witchcliffe          879
# CoffsHarbour         869
# Sydney               865
# Darwin               852
# MountGinini          819
# NorahHead            808
# Ballarat             781
# GoldCoast            775
# SydneyAirport        774
# Hobart               761
# Watsonia             738
# Newcastle            731
# Wollongong           713
# Brisbane             709
# Williamtown          700
# Launceston           699
# Adelaide             688
# MelbourneAirport     653
# Perth                645
# Sale                 643
# Melbourne            636
# Canberra             629
# Albury               618
# Penrith              595
# Nuriootpa            592
# BadgerysCreek        583
# Tuggeranong          568
# PerthAirport         567
# Bendigo              562
# Richmond             560
# WaggaWagga           536
# Townsville           519
# PearceRAAF           505
# SalmonGums           472
# Moree                394
# Cobar                386
# Mildura              327
# Katherine            265
# AliceSprings         244
# Nhil                 242
# Woomera              202
# Uluru                116
# Name: True, dtype: int64

# %%
df1.iloc[:, 1].sort_values(ascending=False).index
# Out:
# Index(['Portland', 'Cairns', 'Walpole', 'Dartmoor', 'MountGambier',
#        'NorfolkIsland', 'Albany', 'Witchcliffe', 'CoffsHarbour', 'Sydney',
#        'Darwin', 'MountGinini', 'NorahHead', 'Ballarat', 'GoldCoast',
#        'SydneyAirport', 'Hobart', 'Watsonia', 'Newcastle', 'Wollongong',
#        'Brisbane', 'Williamtown', 'Launceston', 'Adelaide', 'MelbourneAirport',
#        'Perth', 'Sale', 'Melbourne', 'Canberra', 'Albury', 'Penrith',
#        'Nuriootpa', 'BadgerysCreek', 'Tuggeranong', 'PerthAirport', 'Bendigo',
#        'Richmond', 'WaggaWagga', 'Townsville', 'PearceRAAF', 'SalmonGums',
#        'Moree', 'Cobar', 'Mildura', 'Katherine', 'AliceSprings', 'Nhil',
#        'Woomera', 'Uluru'],
#       dtype='object', name='Location')

# %%
len(df1.iloc[:, 1].sort_values(ascending = False).index)
# Out:
# 49

# %%
len(df1[1].sort_values(ascending = False).index)
# Out:
# 49

# %%
location = {'Portland':1, 'Cairns':2, 'Walpole':3, 'Dartmoor':4, 'MountGambier':5,
       'NorfolkIsland':6, 'Albany':7, 'Witchcliffe':8, 'CoffsHarbour':9, 'Sydney':10,
       'Darwin':11, 'MountGinini':12, 'NorahHead':13, 'Ballarat':14, 'GoldCoast':15,
       'SydneyAirport':16, 'Hobart':17, 'Watsonia':18, 'Newcastle':19, 'Wollongong':20,
       'Brisbane':21, 'Williamtown':22, 'Launceston':23, 'Adelaide':24, 'MelbourneAirport':25,
       'Perth':26, 'Sale':27, 'Melbourne':28, 'Canberra':29, 'Albury':30, 'Penrith':31,
       'Nuriootpa':32, 'BadgerysCreek':33, 'Tuggeranong':34, 'PerthAirport':35, 'Bendigo':36,
       'Richmond':37, 'WaggaWagga':38, 'Townsville':39, 'PearceRAAF':40, 'SalmonGums':41,
       'Moree':42, 'Cobar':43, 'Mildura':44, 'Katherine':45, 'AliceSprings':46, 'Nhil':47,
       'Woomera':48, 'Uluru':49}
df["Location"] = df["Location"].map(location)

# %%
df["Date"] = pd.to_datetime(df["Date"], format = "%Y-%m-%dT", errors = "coerce")

# %%
df["Date_month"] = df["Date"].dt.month
df["Date_day"] = df["Date"].dt.day

# %%
df
# Out:
#        Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0       NaT        30     13.4     22.9       0.6          2.4       8.3
# 1       NaT        30      7.4     25.1       0.0          3.6      10.0
# 2       NaT        30     12.9     25.7       0.0          2.6       4.4
# 3       NaT        30      9.2     28.0       0.0         18.4       8.9
# 4       NaT        30     17.5     32.3       1.0          5.4       3.0
# ...     ...       ...      ...      ...       ...          ...       ...
# 145455  NaT        49      2.8     23.4       0.0          1.4       7.8
# 145456  NaT        49      3.6     25.3       0.0          7.6      13.5
# 145457  NaT        49      5.4     26.9       0.0          6.8      11.0
# 145458  NaT        49      7.8     27.0       0.0          2.6      13.2
# 145459  NaT        49     14.9     22.6       0.0          1.4       0.7
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  \
# 0               4.0           44.0         5.0         3.0          20.0
# 1               2.0           44.0         0.0         6.0           4.0
# 2               5.0           46.0         5.0         6.0          19.0
# 3              11.0           24.0        13.0        14.0          11.0
# 4               4.0           41.0        12.0         0.0           7.0
# ...             ...            ...         ...         ...           ...
# 145455         15.0           31.0        13.0        13.0          13.0
# 145456          0.0           22.0        13.0         2.0          13.0
# 145457          3.0           37.0        13.0         3.0           9.0
# 145458         12.0           28.0        11.0         2.0          13.0
# 145459          4.0           39.0        14.0        15.0          17.0
#
#         WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 0               24.0         71.0         22.0       1007.7       1007.1
# 1               22.0         44.0         25.0       1010.6       1007.8
# 2               26.0         38.0         30.0       1007.6       1008.7
# 3                9.0         45.0         16.0       1017.6       1012.8
# 4               20.0         82.0         33.0       1010.8       1006.0
# ...              ...          ...          ...          ...          ...
# 145455          11.0         51.0         24.0       1024.6       1020.3
# 145456           9.0         56.0         21.0       1023.5       1019.1
# 145457           9.0         53.0         24.0       1021.0       1016.8
# 145458           7.0         51.0         24.0       1019.4       1016.5
# 145459          17.0         62.0         36.0       1020.2       1017.9
#
#         Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  \
# 0            8.0       0.0     16.9     21.8      False         False
# 1            7.0       1.0     17.2     24.3      False         False
# 2            8.0       2.0     21.0     23.2      False         False
# 3            0.0       5.0     18.1     26.5      False         False
# 4            7.0       8.0     17.8     29.7      False         False
# ...          ...       ...      ...      ...        ...           ...
# 145455       1.0       1.0     10.1     22.4      False         False
# 145456       8.0       5.0     10.9     24.5      False         False
# 145457       8.0       1.0     12.5     26.1      False         False
# 145458       3.0       2.0     15.1     26.0      False         False
# 145459       8.0       8.0     15.0     20.9      False         False
#
#         Date_month  Date_day
# 0              NaN       NaN
# 1              NaN       NaN
# 2              NaN       NaN
# 3              NaN       NaN
# 4              NaN       NaN
# ...            ...       ...
# 145455         NaN       NaN
# 145456         NaN       NaN
# 145457         NaN       NaN
# 145458         NaN       NaN
# 145459         NaN       NaN
#
# [145460 rows x 25 columns]

# %%
corrmat = df.corr()
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(corrmat,annot=True)

# %%
sns.countplot(df["RainTomorrow"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-b10bbe5958b0> in <cell line: 0>()
# ----> 1 sns.countplot(df["RainTomorrow"])
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2673     aggregator = EstimateAggregator("sum", errorbar=None)
#    2674
# -> 2675     p.plot_bars(
#    2676         aggregator=aggregator,
#    2677         dodge=dodge,
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in plot_bars(self, aggregator, dodge, gap, width, fill, color, capsize, err_kws, plot_kws)
#    1278
#    1279             agg_data = sub_data if sub_data.empty else (
# -> 1280                 sub_data
#    1281                 .groupby(self.orient)
#    1282                 .apply(aggregator, agg_var, **groupby_apply_include_groups(False))
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in apply(self, func, include_groups, *args, **kwargs)
#    1817
#    1818         if not include_groups:
# -> 1819             return self._python_apply_general(f, self._obj_with_exclusions)
#    1820
#    1821         # ignore SettingWithCopy here in case the user mutates
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1883             data after applying f
#    1884         """
# -> 1885         values, mutated = self._grouper.apply_groupwise(f, data, self.axis)
#    1886         if not_indexed_same is None:
#    1887             not_indexed_same = mutated
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/ops.py in apply_groupwise(self, f, data, axis)
#     917             # group might be modified
#     918             group_axes = group.axes
# --> 919             res = f(group)
#     920             if not mutated and not _is_indexed_like(res, group_axes, axis):
#     921                 mutated = True
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in f(g)
#    1807                 @wraps(func)
#    1808                 def f(g):
# -> 1809                     return func(g, *args, **kwargs)
#    1810
#    1811             else:
#
# /usr/local/lib/python3.11/dist-packages/seaborn/_statistics.py in __call__(self, data, var)
#     490             estimate = self.estimator(vals)
#     491         else:
# --> 492             estimate = vals.agg(self.estimator)
#     493
#     494         # Options that produce no error bars
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in aggregate(self, func, axis, *args, **kwargs)
#    4764
#    4765         op = SeriesApply(self, func, args=args, kwargs=kwargs)
# -> 4766         result = op.agg()
#    4767         return result
#    4768
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in agg(self)
#    1428
#    1429     def agg(self):
# -> 1430         result = super().agg()
#    1431         if result is None:
#    1432             obj = self.obj
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in agg(self)
#     185
#     186         if isinstance(func, str):
# --> 187             return self.apply_str()
#     188
#     189         if is_dict_like(func):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply_str(self)
#     579         method = getattr(obj, func, None)
#     580         if callable(method):
# --> 581             sig = inspect.getfullargspec(method)
#     582             arg_names = (*sig.args, *sig.kwonlyargs)
#     583             if self.axis != 0 and (
#
# /usr/lib/python3.11/inspect.py in getfullargspec(func)
#    1389     for param in sig.parameters.values():
#    1390         kind = param.kind
# -> 1391         name = param.name
#    1392
#    1393         if kind is _POSITIONAL_ONLY:
#
# /usr/lib/python3.11/inspect.py in name(self)
#    2720         self._annotation = state['_annotation']
#    2721
# -> 2722     @property
#    2723     def name(self):
#    2724         return self._name
#
# KeyboardInterrupt:

# %%
df
# Out:
#        Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0       NaT        30     13.4     22.9       0.6          2.4       8.3
# 1       NaT        30      7.4     25.1       0.0          3.6      10.0
# 2       NaT        30     12.9     25.7       0.0          2.6       4.4
# 3       NaT        30      9.2     28.0       0.0         18.4       8.9
# 4       NaT        30     17.5     32.3       1.0          5.4       3.0
# ...     ...       ...      ...      ...       ...          ...       ...
# 145455  NaT        49      2.8     23.4       0.0          1.4       7.8
# 145456  NaT        49      3.6     25.3       0.0          7.6      13.5
# 145457  NaT        49      5.4     26.9       0.0          6.8      11.0
# 145458  NaT        49      7.8     27.0       0.0          2.6      13.2
# 145459  NaT        49     14.9     22.6       0.0          1.4       0.7
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  \
# 0               4.0           44.0         5.0         3.0          20.0
# 1               2.0           44.0         0.0         6.0           4.0
# 2               5.0           46.0         5.0         6.0          19.0
# 3              11.0           24.0        13.0        14.0          11.0
# 4               4.0           41.0        12.0         0.0           7.0
# ...             ...            ...         ...         ...           ...
# 145455         15.0           31.0        13.0        13.0          13.0
# 145456          0.0           22.0        13.0         2.0          13.0
# 145457          3.0           37.0        13.0         3.0           9.0
# 145458         12.0           28.0        11.0         2.0          13.0
# 145459          4.0           39.0        14.0        15.0          17.0
#
#         WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 0               24.0         71.0         22.0       1007.7       1007.1
# 1               22.0         44.0         25.0       1010.6       1007.8
# 2               26.0         38.0         30.0       1007.6       1008.7
# 3                9.0         45.0         16.0       1017.6       1012.8
# 4               20.0         82.0         33.0       1010.8       1006.0
# ...              ...          ...          ...          ...          ...
# 145455          11.0         51.0         24.0       1024.6       1020.3
# 145456           9.0         56.0         21.0       1023.5       1019.1
# 145457           9.0         53.0         24.0       1021.0       1016.8
# 145458           7.0         51.0         24.0       1019.4       1016.5
# 145459          17.0         62.0         36.0       1020.2       1017.9
#
#         Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  \
# 0            8.0       0.0     16.9     21.8      False         False
# 1            7.0       1.0     17.2     24.3      False         False
# 2            8.0       2.0     21.0     23.2      False         False
# 3            0.0       5.0     18.1     26.5      False         False
# 4            7.0       8.0     17.8     29.7      False         False
# ...          ...       ...      ...      ...        ...           ...
# 145455       1.0       1.0     10.1     22.4      False         False
# 145456       8.0       5.0     10.9     24.5      False         False
# 145457       8.0       1.0     12.5     26.1      False         False
# 145458       3.0       2.0     15.1     26.0      False         False
# 145459       8.0       8.0     15.0     20.9      False         False
#
#         Date_month  Date_day
# 0              NaN       NaN
# 1              NaN       NaN
# 2              NaN       NaN
# 3              NaN       NaN
# 4              NaN       NaN
# ...            ...       ...
# 145455         NaN       NaN
# 145456         NaN       NaN
# 145457         NaN       NaN
# 145458         NaN       NaN
# 145459         NaN       NaN
#
# [145460 rows x 25 columns]

# %%
for feature in continuous_feature:
    data=df.copy()
    sns.boxplot(data[feature])
    plt.title(feature)
    plt.figure(figsize=(15,15))

# %%
for feature in continuous_feature:
    print(feature)
# Out:
# MinTemp
# MaxTemp
# Rainfall
# Evaporation
# Sunshine
# WindGustSpeed
# WindSpeed9am
# WindSpeed3pm
# Humidity9am
# Humidity3pm
# Pressure9am
# Pressure3pm
# Temp9am
# Temp3pm

# %%
IQR=df.MinTemp.quantile(0.75)-df.MinTemp.quantile(0.25)
lower_bridge=df.MinTemp.quantile(0.25)-(IQR*1.5)
upper_bridge=df.MinTemp.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -5.950000000000002 30.450000000000003

# %%
df.loc[df['MinTemp']>=30.45,'MinTemp']=30.45
df.loc[df['MinTemp']<=-5.95,'MinTemp']=-5.95

# %%
IQR=df.MaxTemp.quantile(0.75)-df.MaxTemp.quantile(0.25)
lower_bridge=df.MaxTemp.quantile(0.25)-(IQR*1.5)
upper_bridge=df.MaxTemp.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 2.700000000000001 43.5

# %%
df.loc[df['MaxTemp']>=43.5,'MaxTemp']=43.5
df.loc[df['MaxTemp']<=2.7,'MaxTemp']=2.7

# %%
IQR=df.Rainfall.quantile(0.75)-df.Rainfall.quantile(0.25)
lower_bridge=df.Rainfall.quantile(0.25)-(IQR*1.5)
upper_bridge=df.Rainfall.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -0.8999999999999999 1.5

# %%
df.loc[df['Rainfall']>=1.5,'Rainfall']=1.5
df.loc[df['Rainfall']<=-0.89,'Rainfall']=-0.89

# %%
IQR=df.Evaporation.quantile(0.75)-df.Evaporation.quantile(0.25)
lower_bridge=df.Evaporation.quantile(0.25)-(IQR*1.5)
upper_bridge=df.Evaporation.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -4.600000000000001 14.600000000000001

# %%
df.loc[df['Evaporation']>=14.6,'Evaporation']=14.6
df.loc[df['Evaporation']<=-4.6,'Evaporation']=-4.6

# %%
IQR=df.WindGustSpeed.quantile(0.75)-df.WindGustSpeed.quantile(0.25)
lower_bridge=df.WindGustSpeed.quantile(0.25)-(IQR*1.5)
upper_bridge=df.WindGustSpeed.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 8.5 68.5

# %%
df.loc[df['WindGustSpeed']>=68.5,'WindGustSpeed']=68.5
df.loc[df['WindGustSpeed']<=8.5,'WindGustSpeed']=8.5

# %%
IQR=df.WindSpeed9am.quantile(0.75)-df.WindSpeed9am.quantile(0.25)
lower_bridge=df.WindSpeed9am.quantile(0.25)-(IQR*1.5)
upper_bridge=df.WindSpeed9am.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -11.0 37.0

# %%
df.loc[df['WindSpeed9am']>=37,'WindSpeed9am']=37
df.loc[df['WindSpeed9am']<=-11,'WindSpeed9am']=-11

# %%
IQR=df.WindSpeed3pm.quantile(0.75)-df.WindSpeed3pm.quantile(0.25)
lower_bridge=df.WindSpeed3pm.quantile(0.25)-(IQR*1.5)
upper_bridge=df.WindSpeed3pm.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -3.5 40.5

# %%
df.loc[df['WindSpeed3pm']>40.5,'WindSpeed3pm']=40.5
df.loc[df['WindSpeed3pm']<=-3.5,'WindSpeed3pm']=-3.5

# %%
IQR=df.Humidity9am.quantile(0.75)-df.Humidity9am.quantile(0.25)
lower_bridge=df.Humidity9am.quantile(0.25)-(IQR*1.5)
upper_bridge=df.Humidity9am.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 18.0 122.0

# %%
df.loc[df['Humidity9am']>=122,'Humidity9am']=122
df.loc[df['Humidity9am']<=18,'Humidity9am']=18

# %%
IQR=df.Pressure9am.quantile(0.75)-df.Pressure9am.quantile(0.25)
lower_bridge=df.Pressure9am.quantile(0.25)-(IQR*1.5)
upper_bridge=df.Pressure9am.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 1001.0500000000001 1034.25

# %%
df.loc[df['Pressure9am']>=1034.25,'Pressure9am']=1034.25
df.loc[df['Pressure9am']<=1001.05,'Pressure9am']=1001.05

# %%
IQR=df.Pressure3pm.quantile(0.75)-df.Pressure3pm.quantile(0.25)
lower_bridge=df.Pressure3pm.quantile(0.25)-(IQR*1.5)
upper_bridge=df.Pressure3pm.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 998.6500000000001 1031.85

# %%
df.loc[df['Pressure3pm']>=1031.85,'Pressure3pm']=1031.85
df.loc[df['Pressure3pm']<=998.65,'Pressure3pm']=998.65

# %%
IQR=df.Temp9am.quantile(0.75)-df.Temp9am.quantile(0.25)
lower_bridge=df.Temp9am.quantile(0.25)-(IQR*1.5)
upper_bridge=df.Temp9am.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -1.4999999999999982 35.3

# %%
df.loc[df['Temp9am']>=35.3,'Temp9am']=35.3
df.loc[df['Temp9am']<=-1.49,'Temp9am']=-1.49

# %%
IQR=df.Temp3pm.quantile(0.75)-df.Temp3pm.quantile(0.25)
lower_bridge=df.Temp3pm.quantile(0.25)-(IQR*1.5)
upper_bridge=df.Temp3pm.quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 2.4499999999999993 40.45

# %%
df.loc[df['Temp3pm']>=40.45,'Temp3pm']=40.45
df.loc[df['Temp3pm']<=2.45,'Temp3pm']=2.45

# %%
for feature in continuous_feature:
    data=df.copy()
    sns.boxplot(data[feature])
    plt.title(feature)
    plt.figure(figsize=(15,15))

# %%
def qq_plots(df, variable):
    plt.figure(figsize=(15,6))
    plt.subplot(1, 2, 1)
    df[variable].hist()
    plt.subplot(1, 2, 2)
    stats.probplot(df[variable], dist="norm", plot=plt)
    plt.show()

# %%
for feature in continuous_feature:
    print(feature)
    plt.figure(figsize=(15,6))
    plt.subplot(1, 2, 1)
    df[feature].hist()
    plt.subplot(1, 2, 2)
    stats.probplot(df[feature], dist="norm", plot=plt)
    plt.show()
# Out:
# MinTemp
# MaxTemp
# Rainfall
# Evaporation
# Sunshine
# WindGustSpeed
# WindSpeed9am
# WindSpeed3pm
# Humidity9am
# Humidity3pm
# Pressure9am
# Pressure3pm
# Temp9am
# Temp3pm

# %%
df.to_csv("preprocessed_1.csv", index=False)

# %%
X = df.drop(["RainTomorrow", "Date"], axis=1)
Y = df["RainTomorrow"]

# %%
# scaler = RobustScaler()
# X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size =0.2, stratify = Y, random_state = 0)

# %%
y_train
# Out:
# 43447     False
# 140904    False
# 54615     False
# 109793    False
# 74462     False
#           ...
# 106567    False
# 52791      True
# 56339     False
# 82299      True
# 115175    False
# Name: RainTomorrow, Length: 116368, dtype: bool

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="mean")  # or median, depending on the data
X_train = imputer.fit_transform(X_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: ['Date_month' 'Date_day']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(

# %%
sm=SMOTE(random_state=0)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)
print("The number of classes before fit {}".format(Counter(y_train)))
print("The number of classes after fit {}".format(Counter(y_train_res)))
# Out:
# The number of classes before fit Counter({False: 90866, True: 25502})
# The number of classes after fit Counter({False: 90866, True: 90866})

# %%
cat = CatBoostClassifier(iterations=2000, eval_metric = "AUC")
cat.fit(X_train_res, y_train_res)
# Out:
# Learning rate set to 0.050311
# 0:	total: 132ms	remaining: 4m 23s
# 1:	total: 230ms	remaining: 3m 50s
# 2:	total: 327ms	remaining: 3m 37s
# 3:	total: 378ms	remaining: 3m 8s
# 4:	total: 421ms	remaining: 2m 47s
# 5:	total: 466ms	remaining: 2m 34s
# 6:	total: 528ms	remaining: 2m 30s
# 7:	total: 575ms	remaining: 2m 23s
# 8:	total: 621ms	remaining: 2m 17s
# 9:	total: 664ms	remaining: 2m 12s
# 10:	total: 707ms	remaining: 2m 7s
# 11:	total: 751ms	remaining: 2m 4s
# 12:	total: 795ms	remaining: 2m 1s
# 13:	total: 840ms	remaining: 1m 59s
# 14:	total: 884ms	remaining: 1m 56s
# 15:	total: 933ms	remaining: 1m 55s
# 16:	total: 983ms	remaining: 1m 54s
# 17:	total: 1.03s	remaining: 1m 53s
# 18:	total: 1.07s	remaining: 1m 51s
# 19:	total: 1.12s	remaining: 1m 50s
# 20:	total: 1.17s	remaining: 1m 50s
# 21:	total: 1.21s	remaining: 1m 49s
# 22:	total: 1.26s	remaining: 1m 48s
# 23:	total: 1.3s	remaining: 1m 47s
# 24:	total: 1.34s	remaining: 1m 46s
# 25:	total: 1.4s	remaining: 1m 46s
# 26:	total: 1.44s	remaining: 1m 45s
# 27:	total: 1.48s	remaining: 1m 44s
# 28:	total: 1.54s	remaining: 1m 44s
# 29:	total: 1.59s	remaining: 1m 44s
# 30:	total: 1.63s	remaining: 1m 43s
# 31:	total: 1.67s	remaining: 1m 42s
# 32:	total: 1.71s	remaining: 1m 42s
# 33:	total: 1.76s	remaining: 1m 41s
# 34:	total: 1.8s	remaining: 1m 41s
# 35:	total: 1.85s	remaining: 1m 41s
# 36:	total: 1.89s	remaining: 1m 40s
# 37:	total: 1.94s	remaining: 1m 40s
# 38:	total: 1.98s	remaining: 1m 39s
# 39:	total: 2.02s	remaining: 1m 39s
# 40:	total: 2.07s	remaining: 1m 38s
# 41:	total: 2.11s	remaining: 1m 38s
# 42:	total: 2.16s	remaining: 1m 38s
# 43:	total: 2.2s	remaining: 1m 37s
# 44:	total: 2.24s	remaining: 1m 37s
# 45:	total: 2.29s	remaining: 1m 37s
# 46:	total: 2.34s	remaining: 1m 37s
# 47:	total: 2.38s	remaining: 1m 36s
# 48:	total: 2.42s	remaining: 1m 36s
# 49:	total: 2.46s	remaining: 1m 36s
# 50:	total: 2.51s	remaining: 1m 35s
# 51:	total: 2.57s	remaining: 1m 36s
# 52:	total: 2.61s	remaining: 1m 35s
# 53:	total: 2.65s	remaining: 1m 35s
# 54:	total: 2.69s	remaining: 1m 35s
# 55:	total: 2.74s	remaining: 1m 35s
# 56:	total: 2.78s	remaining: 1m 34s
# 57:	total: 2.83s	remaining: 1m 34s
# 58:	total: 2.87s	remaining: 1m 34s
# 59:	total: 2.92s	remaining: 1m 34s
# 60:	total: 2.96s	remaining: 1m 34s
# 61:	total: 3s	remaining: 1m 33s
# 62:	total: 3.05s	remaining: 1m 33s
# 63:	total: 3.1s	remaining: 1m 33s
# 64:	total: 3.14s	remaining: 1m 33s
# 65:	total: 3.19s	remaining: 1m 33s
# 66:	total: 3.23s	remaining: 1m 33s
# 67:	total: 3.27s	remaining: 1m 33s
# 68:	total: 3.32s	remaining: 1m 32s
# 69:	total: 3.37s	remaining: 1m 32s
# 70:	total: 3.41s	remaining: 1m 32s
# 71:	total: 3.45s	remaining: 1m 32s
# 72:	total: 3.49s	remaining: 1m 32s
# 73:	total: 3.53s	remaining: 1m 31s
# 74:	total: 3.59s	remaining: 1m 32s
# 75:	total: 3.64s	remaining: 1m 32s
# 76:	total: 3.68s	remaining: 1m 31s
# 77:	total: 3.72s	remaining: 1m 31s
# 78:	total: 3.77s	remaining: 1m 31s
# 79:	total: 3.81s	remaining: 1m 31s
# 80:	total: 3.86s	remaining: 1m 31s
# 81:	total: 3.9s	remaining: 1m 31s
# 82:	total: 3.94s	remaining: 1m 31s
# 83:	total: 3.99s	remaining: 1m 31s
# 84:	total: 4.04s	remaining: 1m 31s
# 85:	total: 4.08s	remaining: 1m 30s
# 86:	total: 4.12s	remaining: 1m 30s
# 87:	total: 4.17s	remaining: 1m 30s
# 88:	total: 4.21s	remaining: 1m 30s
# 89:	total: 4.25s	remaining: 1m 30s
# 90:	total: 4.3s	remaining: 1m 30s
# 91:	total: 4.35s	remaining: 1m 30s
# 92:	total: 4.39s	remaining: 1m 29s
# 93:	total: 4.43s	remaining: 1m 29s
# 94:	total: 4.48s	remaining: 1m 29s
# 95:	total: 4.52s	remaining: 1m 29s
# 96:	total: 4.58s	remaining: 1m 29s
# 97:	total: 4.63s	remaining: 1m 29s
# 98:	total: 4.66s	remaining: 1m 29s
# 99:	total: 4.71s	remaining: 1m 29s
# 100:	total: 4.75s	remaining: 1m 29s
# 101:	total: 4.8s	remaining: 1m 29s
# 102:	total: 4.83s	remaining: 1m 29s
# 103:	total: 4.88s	remaining: 1m 28s
# 104:	total: 4.93s	remaining: 1m 28s
# 105:	total: 4.97s	remaining: 1m 28s
# 106:	total: 5.01s	remaining: 1m 28s
# 107:	total: 5.06s	remaining: 1m 28s
# 108:	total: 5.1s	remaining: 1m 28s
# 109:	total: 5.14s	remaining: 1m 28s
# 110:	total: 5.19s	remaining: 1m 28s
# 111:	total: 5.23s	remaining: 1m 28s
# 112:	total: 5.27s	remaining: 1m 28s
# 113:	total: 5.32s	remaining: 1m 27s
# 114:	total: 5.36s	remaining: 1m 27s
# 115:	total: 5.41s	remaining: 1m 27s
# 116:	total: 5.45s	remaining: 1m 27s
# 117:	total: 5.5s	remaining: 1m 27s
# 118:	total: 5.54s	remaining: 1m 27s
# 119:	total: 5.59s	remaining: 1m 27s
# 120:	total: 5.64s	remaining: 1m 27s
# 121:	total: 5.68s	remaining: 1m 27s
# 122:	total: 5.73s	remaining: 1m 27s
# 123:	total: 5.77s	remaining: 1m 27s
# 124:	total: 5.82s	remaining: 1m 27s
# 125:	total: 5.87s	remaining: 1m 27s
# 126:	total: 5.91s	remaining: 1m 27s
# 127:	total: 5.95s	remaining: 1m 27s
# 128:	total: 5.99s	remaining: 1m 26s
# 129:	total: 6.03s	remaining: 1m 26s
# 130:	total: 6.08s	remaining: 1m 26s
# 131:	total: 6.13s	remaining: 1m 26s
# 132:	total: 6.17s	remaining: 1m 26s
# 133:	total: 6.21s	remaining: 1m 26s
# 134:	total: 6.26s	remaining: 1m 26s
# 135:	total: 6.3s	remaining: 1m 26s
# 136:	total: 6.35s	remaining: 1m 26s
# 137:	total: 6.39s	remaining: 1m 26s
# 138:	total: 6.43s	remaining: 1m 26s
# 139:	total: 6.47s	remaining: 1m 25s
# 140:	total: 6.52s	remaining: 1m 25s
# 141:	total: 6.56s	remaining: 1m 25s
# 142:	total: 6.61s	remaining: 1m 25s
# 143:	total: 6.66s	remaining: 1m 25s
# 144:	total: 6.7s	remaining: 1m 25s
# 145:	total: 6.75s	remaining: 1m 25s
# 146:	total: 6.79s	remaining: 1m 25s
# 147:	total: 6.83s	remaining: 1m 25s
# 148:	total: 6.87s	remaining: 1m 25s
# 149:	total: 6.91s	remaining: 1m 25s
# 150:	total: 6.96s	remaining: 1m 25s
# 151:	total: 7s	remaining: 1m 25s
# 152:	total: 7.04s	remaining: 1m 25s
# 153:	total: 7.08s	remaining: 1m 24s
# 154:	total: 7.13s	remaining: 1m 24s
# 155:	total: 7.17s	remaining: 1m 24s
# 156:	total: 7.22s	remaining: 1m 24s
# 157:	total: 7.26s	remaining: 1m 24s
# 158:	total: 7.3s	remaining: 1m 24s
# 159:	total: 7.35s	remaining: 1m 24s
# 160:	total: 7.4s	remaining: 1m 24s
# 161:	total: 7.45s	remaining: 1m 24s
# 162:	total: 7.49s	remaining: 1m 24s
# 163:	total: 7.54s	remaining: 1m 24s
# 164:	total: 7.58s	remaining: 1m 24s
# 165:	total: 7.63s	remaining: 1m 24s
# 166:	total: 7.69s	remaining: 1m 24s
# 167:	total: 7.74s	remaining: 1m 24s
# 168:	total: 7.78s	remaining: 1m 24s
# 169:	total: 7.82s	remaining: 1m 24s
# 170:	total: 7.86s	remaining: 1m 24s
# 171:	total: 7.91s	remaining: 1m 24s
# 172:	total: 7.96s	remaining: 1m 24s
# 173:	total: 8.02s	remaining: 1m 24s
# 174:	total: 8.07s	remaining: 1m 24s
# 175:	total: 8.11s	remaining: 1m 24s
# 176:	total: 8.15s	remaining: 1m 23s
# 177:	total: 8.2s	remaining: 1m 23s
# 178:	total: 8.24s	remaining: 1m 23s
# 179:	total: 8.29s	remaining: 1m 23s
# 180:	total: 8.34s	remaining: 1m 23s
# 181:	total: 8.39s	remaining: 1m 23s
# 182:	total: 8.43s	remaining: 1m 23s
# 183:	total: 8.48s	remaining: 1m 23s
# 184:	total: 8.53s	remaining: 1m 23s
# 185:	total: 8.57s	remaining: 1m 23s
# 186:	total: 8.61s	remaining: 1m 23s
# 187:	total: 8.67s	remaining: 1m 23s
# 188:	total: 8.72s	remaining: 1m 23s
# 189:	total: 8.76s	remaining: 1m 23s
# 190:	total: 8.81s	remaining: 1m 23s
# 191:	total: 8.86s	remaining: 1m 23s
# 192:	total: 8.9s	remaining: 1m 23s
# 193:	total: 8.95s	remaining: 1m 23s
# 194:	total: 9s	remaining: 1m 23s
# 195:	total: 9.04s	remaining: 1m 23s
# 196:	total: 9.08s	remaining: 1m 23s
# 197:	total: 9.13s	remaining: 1m 23s
# 198:	total: 9.18s	remaining: 1m 23s
# 199:	total: 9.22s	remaining: 1m 23s
# 200:	total: 9.27s	remaining: 1m 22s
# 201:	total: 9.31s	remaining: 1m 22s
# 202:	total: 9.36s	remaining: 1m 22s
# 203:	total: 9.4s	remaining: 1m 22s
# 204:	total: 9.45s	remaining: 1m 22s
# 205:	total: 9.49s	remaining: 1m 22s
# 206:	total: 9.54s	remaining: 1m 22s
# 207:	total: 9.58s	remaining: 1m 22s
# 208:	total: 9.62s	remaining: 1m 22s
# 209:	total: 9.68s	remaining: 1m 22s
# 210:	total: 9.72s	remaining: 1m 22s
# 211:	total: 9.77s	remaining: 1m 22s
# 212:	total: 9.81s	remaining: 1m 22s
# 213:	total: 9.85s	remaining: 1m 22s
# 214:	total: 9.9s	remaining: 1m 22s
# 215:	total: 9.95s	remaining: 1m 22s
# 216:	total: 9.99s	remaining: 1m 22s
# 217:	total: 10s	remaining: 1m 22s
# 218:	total: 10.1s	remaining: 1m 21s
# 219:	total: 10.1s	remaining: 1m 21s
# 220:	total: 10.2s	remaining: 1m 21s
# 221:	total: 10.2s	remaining: 1m 21s
# 222:	total: 10.3s	remaining: 1m 21s
# 223:	total: 10.3s	remaining: 1m 21s
# 224:	total: 10.4s	remaining: 1m 21s
# 225:	total: 10.5s	remaining: 1m 22s
# 226:	total: 10.5s	remaining: 1m 22s
# 227:	total: 10.6s	remaining: 1m 22s
# 228:	total: 10.7s	remaining: 1m 22s
# 229:	total: 10.8s	remaining: 1m 23s
# 230:	total: 10.9s	remaining: 1m 23s
# 231:	total: 10.9s	remaining: 1m 23s
# 232:	total: 11s	remaining: 1m 23s
# 233:	total: 11.1s	remaining: 1m 24s
# 234:	total: 11.2s	remaining: 1m 24s
# 235:	total: 11.3s	remaining: 1m 24s
# 236:	total: 11.4s	remaining: 1m 24s
# 237:	total: 11.5s	remaining: 1m 25s
# 238:	total: 11.6s	remaining: 1m 25s
# 239:	total: 11.7s	remaining: 1m 25s
# 240:	total: 11.8s	remaining: 1m 26s
# 241:	total: 11.9s	remaining: 1m 26s
# 242:	total: 12s	remaining: 1m 26s
# 243:	total: 12.1s	remaining: 1m 26s
# 244:	total: 12.1s	remaining: 1m 27s
# 245:	total: 12.2s	remaining: 1m 27s
# 246:	total: 12.3s	remaining: 1m 27s
# 247:	total: 12.4s	remaining: 1m 27s
# 248:	total: 12.5s	remaining: 1m 27s
# 249:	total: 12.6s	remaining: 1m 28s
# 250:	total: 12.7s	remaining: 1m 28s
# 251:	total: 12.8s	remaining: 1m 28s
# 252:	total: 12.9s	remaining: 1m 28s
# 253:	total: 13s	remaining: 1m 29s
# 254:	total: 13s	remaining: 1m 29s
# 255:	total: 13.1s	remaining: 1m 29s
# 256:	total: 13.2s	remaining: 1m 29s
# 257:	total: 13.3s	remaining: 1m 29s
# 258:	total: 13.4s	remaining: 1m 29s
# 259:	total: 13.5s	remaining: 1m 30s
# 260:	total: 13.5s	remaining: 1m 30s
# 261:	total: 13.6s	remaining: 1m 30s
# 262:	total: 13.7s	remaining: 1m 30s
# 263:	total: 13.8s	remaining: 1m 30s
# 264:	total: 13.9s	remaining: 1m 31s
# 265:	total: 14s	remaining: 1m 31s
# 266:	total: 14.1s	remaining: 1m 31s
# 267:	total: 14.2s	remaining: 1m 31s
# 268:	total: 14.3s	remaining: 1m 31s
# 269:	total: 14.4s	remaining: 1m 32s
# 270:	total: 14.5s	remaining: 1m 32s
# 271:	total: 14.6s	remaining: 1m 32s
# 272:	total: 14.6s	remaining: 1m 32s
# 273:	total: 14.7s	remaining: 1m 32s
# 274:	total: 14.7s	remaining: 1m 32s
# 275:	total: 14.8s	remaining: 1m 32s
# 276:	total: 14.8s	remaining: 1m 32s
# 277:	total: 14.9s	remaining: 1m 32s
# 278:	total: 14.9s	remaining: 1m 32s
# 279:	total: 15s	remaining: 1m 31s
# 280:	total: 15s	remaining: 1m 31s
# 281:	total: 15s	remaining: 1m 31s
# 282:	total: 15.1s	remaining: 1m 31s
# 283:	total: 15.1s	remaining: 1m 31s
# 284:	total: 15.2s	remaining: 1m 31s
# 285:	total: 15.2s	remaining: 1m 31s
# 286:	total: 15.3s	remaining: 1m 31s
# 287:	total: 15.3s	remaining: 1m 31s
# 288:	total: 15.4s	remaining: 1m 30s
# 289:	total: 15.4s	remaining: 1m 30s
# 290:	total: 15.4s	remaining: 1m 30s
# 291:	total: 15.5s	remaining: 1m 30s
# 292:	total: 15.5s	remaining: 1m 30s
# 293:	total: 15.6s	remaining: 1m 30s
# 294:	total: 15.6s	remaining: 1m 30s
# 295:	total: 15.7s	remaining: 1m 30s
# 296:	total: 15.7s	remaining: 1m 30s
# 297:	total: 15.8s	remaining: 1m 30s
# 298:	total: 15.8s	remaining: 1m 29s
# 299:	total: 15.8s	remaining: 1m 29s
# 300:	total: 15.9s	remaining: 1m 29s
# 301:	total: 15.9s	remaining: 1m 29s
# 302:	total: 16s	remaining: 1m 29s
# 303:	total: 16s	remaining: 1m 29s
# 304:	total: 16.1s	remaining: 1m 29s
# 305:	total: 16.1s	remaining: 1m 29s
# 306:	total: 16.2s	remaining: 1m 29s
# 307:	total: 16.2s	remaining: 1m 29s
# 308:	total: 16.2s	remaining: 1m 28s
# 309:	total: 16.3s	remaining: 1m 28s
# 310:	total: 16.3s	remaining: 1m 28s
# 311:	total: 16.4s	remaining: 1m 28s
# 312:	total: 16.4s	remaining: 1m 28s
# 313:	total: 16.5s	remaining: 1m 28s
# 314:	total: 16.5s	remaining: 1m 28s
# 315:	total: 16.5s	remaining: 1m 28s
# 316:	total: 16.6s	remaining: 1m 28s
# 317:	total: 16.6s	remaining: 1m 27s
# 318:	total: 16.7s	remaining: 1m 27s
# 319:	total: 16.7s	remaining: 1m 27s
# 320:	total: 16.8s	remaining: 1m 27s
# 321:	total: 16.8s	remaining: 1m 27s
# 322:	total: 16.8s	remaining: 1m 27s
# 323:	total: 16.9s	remaining: 1m 27s
# 324:	total: 16.9s	remaining: 1m 27s
# 325:	total: 17s	remaining: 1m 27s
# 326:	total: 17s	remaining: 1m 27s
# 327:	total: 17.1s	remaining: 1m 27s
# 328:	total: 17.1s	remaining: 1m 26s
# 329:	total: 17.2s	remaining: 1m 26s
# 330:	total: 17.2s	remaining: 1m 26s
# 331:	total: 17.2s	remaining: 1m 26s
# 332:	total: 17.3s	remaining: 1m 26s
# 333:	total: 17.3s	remaining: 1m 26s
# 334:	total: 17.4s	remaining: 1m 26s
# 335:	total: 17.4s	remaining: 1m 26s
# 336:	total: 17.5s	remaining: 1m 26s
# 337:	total: 17.5s	remaining: 1m 26s
# 338:	total: 17.6s	remaining: 1m 26s
# 339:	total: 17.6s	remaining: 1m 25s
# 340:	total: 17.6s	remaining: 1m 25s
# 341:	total: 17.7s	remaining: 1m 25s
# 342:	total: 17.7s	remaining: 1m 25s
# 343:	total: 17.8s	remaining: 1m 25s
# 344:	total: 17.8s	remaining: 1m 25s
# 345:	total: 17.9s	remaining: 1m 25s
# 346:	total: 17.9s	remaining: 1m 25s
# 347:	total: 18s	remaining: 1m 25s
# 348:	total: 18s	remaining: 1m 25s
# 349:	total: 18s	remaining: 1m 25s
# 350:	total: 18.1s	remaining: 1m 25s
# 351:	total: 18.1s	remaining: 1m 24s
# 352:	total: 18.2s	remaining: 1m 24s
# 353:	total: 18.2s	remaining: 1m 24s
# 354:	total: 18.3s	remaining: 1m 24s
# 355:	total: 18.3s	remaining: 1m 24s
# 356:	total: 18.4s	remaining: 1m 24s
# 357:	total: 18.4s	remaining: 1m 24s
# 358:	total: 18.4s	remaining: 1m 24s
# 359:	total: 18.5s	remaining: 1m 24s
# 360:	total: 18.5s	remaining: 1m 24s
# 361:	total: 18.6s	remaining: 1m 24s
# 362:	total: 18.6s	remaining: 1m 24s
# 363:	total: 18.7s	remaining: 1m 23s
# 364:	total: 18.7s	remaining: 1m 23s
# 365:	total: 18.8s	remaining: 1m 23s
# 366:	total: 18.8s	remaining: 1m 23s
# 367:	total: 18.9s	remaining: 1m 23s
# 368:	total: 18.9s	remaining: 1m 23s
# 369:	total: 18.9s	remaining: 1m 23s
# 370:	total: 19s	remaining: 1m 23s
# 371:	total: 19s	remaining: 1m 23s
# 372:	total: 19.1s	remaining: 1m 23s
# 373:	total: 19.1s	remaining: 1m 23s
# 374:	total: 19.2s	remaining: 1m 23s
# 375:	total: 19.2s	remaining: 1m 23s
# 376:	total: 19.3s	remaining: 1m 22s
# 377:	total: 19.3s	remaining: 1m 22s
# 378:	total: 19.3s	remaining: 1m 22s
# 379:	total: 19.4s	remaining: 1m 22s
# 380:	total: 19.4s	remaining: 1m 22s
# 381:	total: 19.5s	remaining: 1m 22s
# 382:	total: 19.5s	remaining: 1m 22s
# 383:	total: 19.6s	remaining: 1m 22s
# 384:	total: 19.6s	remaining: 1m 22s
# 385:	total: 19.6s	remaining: 1m 22s
# 386:	total: 19.7s	remaining: 1m 22s
# 387:	total: 19.7s	remaining: 1m 21s
# 388:	total: 19.8s	remaining: 1m 21s
# 389:	total: 19.8s	remaining: 1m 21s
# 390:	total: 19.9s	remaining: 1m 21s
# 391:	total: 19.9s	remaining: 1m 21s
# 392:	total: 19.9s	remaining: 1m 21s
# 393:	total: 20s	remaining: 1m 21s
# 394:	total: 20s	remaining: 1m 21s
# 395:	total: 20.1s	remaining: 1m 21s
# 396:	total: 20.1s	remaining: 1m 21s
# 397:	total: 20.2s	remaining: 1m 21s
# 398:	total: 20.2s	remaining: 1m 21s
# 399:	total: 20.3s	remaining: 1m 21s
# 400:	total: 20.3s	remaining: 1m 21s
# 401:	total: 20.4s	remaining: 1m 20s
# 402:	total: 20.4s	remaining: 1m 20s
# 403:	total: 20.5s	remaining: 1m 20s
# 404:	total: 20.5s	remaining: 1m 20s
# 405:	total: 20.5s	remaining: 1m 20s
# 406:	total: 20.6s	remaining: 1m 20s
# 407:	total: 20.6s	remaining: 1m 20s
# 408:	total: 20.7s	remaining: 1m 20s
# 409:	total: 20.7s	remaining: 1m 20s
# 410:	total: 20.8s	remaining: 1m 20s
# 411:	total: 20.8s	remaining: 1m 20s
# 412:	total: 20.9s	remaining: 1m 20s
# 413:	total: 20.9s	remaining: 1m 20s
# 414:	total: 21s	remaining: 1m 20s
# 415:	total: 21s	remaining: 1m 20s
# 416:	total: 21.1s	remaining: 1m 19s
# 417:	total: 21.1s	remaining: 1m 19s
# 418:	total: 21.1s	remaining: 1m 19s
# 419:	total: 21.2s	remaining: 1m 19s
# 420:	total: 21.2s	remaining: 1m 19s
# 421:	total: 21.3s	remaining: 1m 19s
# 422:	total: 21.3s	remaining: 1m 19s
# 423:	total: 21.4s	remaining: 1m 19s
# 424:	total: 21.4s	remaining: 1m 19s
# 425:	total: 21.5s	remaining: 1m 19s
# 426:	total: 21.5s	remaining: 1m 19s
# 427:	total: 21.5s	remaining: 1m 19s
# 428:	total: 21.6s	remaining: 1m 19s
# 429:	total: 21.6s	remaining: 1m 18s
# 430:	total: 21.7s	remaining: 1m 18s
# 431:	total: 21.7s	remaining: 1m 18s
# 432:	total: 21.8s	remaining: 1m 18s
# 433:	total: 21.8s	remaining: 1m 18s
# 434:	total: 21.8s	remaining: 1m 18s
# 435:	total: 21.9s	remaining: 1m 18s
# 436:	total: 21.9s	remaining: 1m 18s
# 437:	total: 22s	remaining: 1m 18s
# 438:	total: 22s	remaining: 1m 18s
# 439:	total: 22.1s	remaining: 1m 18s
# 440:	total: 22.1s	remaining: 1m 18s
# 441:	total: 22.2s	remaining: 1m 18s
# 442:	total: 22.2s	remaining: 1m 18s
# 443:	total: 22.3s	remaining: 1m 17s
# 444:	total: 22.3s	remaining: 1m 17s
# 445:	total: 22.3s	remaining: 1m 17s
# 446:	total: 22.4s	remaining: 1m 17s
# 447:	total: 22.4s	remaining: 1m 17s
# 448:	total: 22.5s	remaining: 1m 17s
# 449:	total: 22.5s	remaining: 1m 17s
# 450:	total: 22.6s	remaining: 1m 17s
# 451:	total: 22.6s	remaining: 1m 17s
# 452:	total: 22.6s	remaining: 1m 17s
# 453:	total: 22.7s	remaining: 1m 17s
# 454:	total: 22.7s	remaining: 1m 17s
# 455:	total: 22.8s	remaining: 1m 17s
# 456:	total: 22.8s	remaining: 1m 17s
# 457:	total: 22.9s	remaining: 1m 16s
# 458:	total: 22.9s	remaining: 1m 16s
# 459:	total: 23s	remaining: 1m 16s
# 460:	total: 23s	remaining: 1m 16s
# 461:	total: 23s	remaining: 1m 16s
# 462:	total: 23.1s	remaining: 1m 16s
# 463:	total: 23.1s	remaining: 1m 16s
# 464:	total: 23.2s	remaining: 1m 16s
# 465:	total: 23.2s	remaining: 1m 16s
# 466:	total: 23.3s	remaining: 1m 16s
# 467:	total: 23.3s	remaining: 1m 16s
# 468:	total: 23.4s	remaining: 1m 16s
# 469:	total: 23.4s	remaining: 1m 16s
# 470:	total: 23.4s	remaining: 1m 16s
# 471:	total: 23.5s	remaining: 1m 16s
# 472:	total: 23.5s	remaining: 1m 15s
# 473:	total: 23.6s	remaining: 1m 15s
# 474:	total: 23.6s	remaining: 1m 15s
# 475:	total: 23.7s	remaining: 1m 15s
# 476:	total: 23.7s	remaining: 1m 15s
# 477:	total: 23.7s	remaining: 1m 15s
# 478:	total: 23.8s	remaining: 1m 15s
# 479:	total: 23.8s	remaining: 1m 15s
# 480:	total: 23.9s	remaining: 1m 15s
# 481:	total: 23.9s	remaining: 1m 15s
# 482:	total: 24s	remaining: 1m 15s
# 483:	total: 24s	remaining: 1m 15s
# 484:	total: 24s	remaining: 1m 15s
# 485:	total: 24.1s	remaining: 1m 15s
# 486:	total: 24.1s	remaining: 1m 15s
# 487:	total: 24.2s	remaining: 1m 14s
# 488:	total: 24.2s	remaining: 1m 14s
# 489:	total: 24.3s	remaining: 1m 14s
# 490:	total: 24.3s	remaining: 1m 14s
# 491:	total: 24.4s	remaining: 1m 14s
# 492:	total: 24.4s	remaining: 1m 14s
# 493:	total: 24.4s	remaining: 1m 14s
# 494:	total: 24.5s	remaining: 1m 14s
# 495:	total: 24.5s	remaining: 1m 14s
# 496:	total: 24.6s	remaining: 1m 14s
# 497:	total: 24.6s	remaining: 1m 14s
# 498:	total: 24.7s	remaining: 1m 14s
# 499:	total: 24.8s	remaining: 1m 14s
# 500:	total: 24.9s	remaining: 1m 14s
# 501:	total: 25s	remaining: 1m 14s
# 502:	total: 25s	remaining: 1m 14s
# 503:	total: 25.1s	remaining: 1m 14s
# 504:	total: 25.2s	remaining: 1m 14s
# 505:	total: 25.3s	remaining: 1m 14s
# 506:	total: 25.4s	remaining: 1m 14s
# 507:	total: 25.5s	remaining: 1m 14s
# 508:	total: 25.6s	remaining: 1m 14s
# 509:	total: 25.7s	remaining: 1m 15s
# 510:	total: 25.8s	remaining: 1m 15s
# 511:	total: 25.8s	remaining: 1m 15s
# 512:	total: 26s	remaining: 1m 15s
# 513:	total: 26s	remaining: 1m 15s
# 514:	total: 26.1s	remaining: 1m 15s
# 515:	total: 26.2s	remaining: 1m 15s
# 516:	total: 26.3s	remaining: 1m 15s
# 517:	total: 26.4s	remaining: 1m 15s
# 518:	total: 26.5s	remaining: 1m 15s
# 519:	total: 26.6s	remaining: 1m 15s
# 520:	total: 26.6s	remaining: 1m 15s
# 521:	total: 26.7s	remaining: 1m 15s
# 522:	total: 26.8s	remaining: 1m 15s
# 523:	total: 26.9s	remaining: 1m 15s
# 524:	total: 27s	remaining: 1m 15s
# 525:	total: 27.1s	remaining: 1m 15s
# 526:	total: 27.2s	remaining: 1m 16s
# 527:	total: 27.3s	remaining: 1m 16s
# 528:	total: 27.4s	remaining: 1m 16s
# 529:	total: 27.5s	remaining: 1m 16s
# 530:	total: 27.6s	remaining: 1m 16s
# 531:	total: 27.7s	remaining: 1m 16s
# 532:	total: 27.7s	remaining: 1m 16s
# 533:	total: 27.8s	remaining: 1m 16s
# 534:	total: 27.9s	remaining: 1m 16s
# 535:	total: 28s	remaining: 1m 16s
# 536:	total: 28.1s	remaining: 1m 16s
# 537:	total: 28.2s	remaining: 1m 16s
# 538:	total: 28.3s	remaining: 1m 16s
# 539:	total: 28.4s	remaining: 1m 16s
# 540:	total: 28.4s	remaining: 1m 16s
# 541:	total: 28.5s	remaining: 1m 16s
# 542:	total: 28.6s	remaining: 1m 16s
# 543:	total: 28.7s	remaining: 1m 16s
# 544:	total: 28.8s	remaining: 1m 16s
# 545:	total: 28.8s	remaining: 1m 16s
# 546:	total: 28.9s	remaining: 1m 16s
# 547:	total: 28.9s	remaining: 1m 16s
# 548:	total: 29s	remaining: 1m 16s
# 549:	total: 29s	remaining: 1m 16s
# 550:	total: 29.1s	remaining: 1m 16s
# 551:	total: 29.1s	remaining: 1m 16s
# 552:	total: 29.2s	remaining: 1m 16s
# 553:	total: 29.2s	remaining: 1m 16s
# 554:	total: 29.3s	remaining: 1m 16s
# 555:	total: 29.3s	remaining: 1m 16s
# 556:	total: 29.4s	remaining: 1m 16s
# 557:	total: 29.4s	remaining: 1m 16s
# 558:	total: 29.5s	remaining: 1m 15s
# 559:	total: 29.5s	remaining: 1m 15s
# 560:	total: 29.5s	remaining: 1m 15s
# 561:	total: 29.6s	remaining: 1m 15s
# 562:	total: 29.6s	remaining: 1m 15s
# 563:	total: 29.7s	remaining: 1m 15s
# 564:	total: 29.7s	remaining: 1m 15s
# 565:	total: 29.8s	remaining: 1m 15s
# 566:	total: 29.8s	remaining: 1m 15s
# 567:	total: 29.8s	remaining: 1m 15s
# 568:	total: 29.9s	remaining: 1m 15s
# 569:	total: 29.9s	remaining: 1m 15s
# 570:	total: 30s	remaining: 1m 15s
# 571:	total: 30s	remaining: 1m 14s
# 572:	total: 30.1s	remaining: 1m 14s
# 573:	total: 30.1s	remaining: 1m 14s
# 574:	total: 30.1s	remaining: 1m 14s
# 575:	total: 30.2s	remaining: 1m 14s
# 576:	total: 30.2s	remaining: 1m 14s
# 577:	total: 30.3s	remaining: 1m 14s
# 578:	total: 30.3s	remaining: 1m 14s
# 579:	total: 30.4s	remaining: 1m 14s
# 580:	total: 30.4s	remaining: 1m 14s
# 581:	total: 30.5s	remaining: 1m 14s
# 582:	total: 30.5s	remaining: 1m 14s
# 583:	total: 30.5s	remaining: 1m 14s
# 584:	total: 30.6s	remaining: 1m 14s
# 585:	total: 30.6s	remaining: 1m 13s
# 586:	total: 30.7s	remaining: 1m 13s
# 587:	total: 30.7s	remaining: 1m 13s
# 588:	total: 30.8s	remaining: 1m 13s
# 589:	total: 30.8s	remaining: 1m 13s
# 590:	total: 30.9s	remaining: 1m 13s
# 591:	total: 30.9s	remaining: 1m 13s
# 592:	total: 30.9s	remaining: 1m 13s
# 593:	total: 31s	remaining: 1m 13s
# 594:	total: 31s	remaining: 1m 13s
# 595:	total: 31.1s	remaining: 1m 13s
# 596:	total: 31.1s	remaining: 1m 13s
# 597:	total: 31.2s	remaining: 1m 13s
# 598:	total: 31.2s	remaining: 1m 13s
# 599:	total: 31.3s	remaining: 1m 12s
# 600:	total: 31.3s	remaining: 1m 12s
# 601:	total: 31.3s	remaining: 1m 12s
# 602:	total: 31.4s	remaining: 1m 12s
# 603:	total: 31.4s	remaining: 1m 12s
# 604:	total: 31.5s	remaining: 1m 12s
# 605:	total: 31.5s	remaining: 1m 12s
# 606:	total: 31.6s	remaining: 1m 12s
# 607:	total: 31.6s	remaining: 1m 12s
# 608:	total: 31.7s	remaining: 1m 12s
# 609:	total: 31.7s	remaining: 1m 12s
# 610:	total: 31.7s	remaining: 1m 12s
# 611:	total: 31.8s	remaining: 1m 12s
# 612:	total: 31.8s	remaining: 1m 12s
# 613:	total: 31.9s	remaining: 1m 11s
# 614:	total: 31.9s	remaining: 1m 11s
# 615:	total: 32s	remaining: 1m 11s
# 616:	total: 32s	remaining: 1m 11s
# 617:	total: 32s	remaining: 1m 11s
# 618:	total: 32.1s	remaining: 1m 11s
# 619:	total: 32.1s	remaining: 1m 11s
# 620:	total: 32.2s	remaining: 1m 11s
# 621:	total: 32.2s	remaining: 1m 11s
# 622:	total: 32.3s	remaining: 1m 11s
# 623:	total: 32.3s	remaining: 1m 11s
# 624:	total: 32.3s	remaining: 1m 11s
# 625:	total: 32.4s	remaining: 1m 11s
# 626:	total: 32.4s	remaining: 1m 11s
# 627:	total: 32.5s	remaining: 1m 10s
# 628:	total: 32.5s	remaining: 1m 10s
# 629:	total: 32.6s	remaining: 1m 10s
# 630:	total: 32.6s	remaining: 1m 10s
# 631:	total: 32.7s	remaining: 1m 10s
# 632:	total: 32.7s	remaining: 1m 10s
# 633:	total: 32.8s	remaining: 1m 10s
# 634:	total: 32.8s	remaining: 1m 10s
# 635:	total: 32.8s	remaining: 1m 10s
# 636:	total: 32.9s	remaining: 1m 10s
# 637:	total: 32.9s	remaining: 1m 10s
# 638:	total: 33s	remaining: 1m 10s
# 639:	total: 33s	remaining: 1m 10s
# 640:	total: 33.1s	remaining: 1m 10s
# 641:	total: 33.1s	remaining: 1m 10s
# 642:	total: 33.1s	remaining: 1m 9s
# 643:	total: 33.2s	remaining: 1m 9s
# 644:	total: 33.2s	remaining: 1m 9s
# 645:	total: 33.3s	remaining: 1m 9s
# 646:	total: 33.3s	remaining: 1m 9s
# 647:	total: 33.4s	remaining: 1m 9s
# 648:	total: 33.4s	remaining: 1m 9s
# 649:	total: 33.5s	remaining: 1m 9s
# 650:	total: 33.5s	remaining: 1m 9s
# 651:	total: 33.5s	remaining: 1m 9s
# 652:	total: 33.6s	remaining: 1m 9s
# 653:	total: 33.6s	remaining: 1m 9s
# 654:	total: 33.7s	remaining: 1m 9s
# 655:	total: 33.7s	remaining: 1m 9s
# 656:	total: 33.7s	remaining: 1m 8s
# 657:	total: 33.8s	remaining: 1m 8s
# 658:	total: 33.8s	remaining: 1m 8s
# 659:	total: 33.9s	remaining: 1m 8s
# 660:	total: 33.9s	remaining: 1m 8s
# 661:	total: 34s	remaining: 1m 8s
# 662:	total: 34s	remaining: 1m 8s
# 663:	total: 34s	remaining: 1m 8s
# 664:	total: 34.1s	remaining: 1m 8s
# 665:	total: 34.1s	remaining: 1m 8s
# 666:	total: 34.2s	remaining: 1m 8s
# 667:	total: 34.2s	remaining: 1m 8s
# 668:	total: 34.3s	remaining: 1m 8s
# 669:	total: 34.3s	remaining: 1m 8s
# 670:	total: 34.4s	remaining: 1m 8s
# 671:	total: 34.4s	remaining: 1m 7s
# 672:	total: 34.5s	remaining: 1m 7s
# 673:	total: 34.5s	remaining: 1m 7s
# 674:	total: 34.5s	remaining: 1m 7s
# 675:	total: 34.6s	remaining: 1m 7s
# 676:	total: 34.6s	remaining: 1m 7s
# 677:	total: 34.7s	remaining: 1m 7s
# 678:	total: 34.7s	remaining: 1m 7s
# 679:	total: 34.8s	remaining: 1m 7s
# 680:	total: 34.8s	remaining: 1m 7s
# 681:	total: 34.9s	remaining: 1m 7s
# 682:	total: 34.9s	remaining: 1m 7s
# 683:	total: 34.9s	remaining: 1m 7s
# 684:	total: 35s	remaining: 1m 7s
# 685:	total: 35s	remaining: 1m 7s
# 686:	total: 35.1s	remaining: 1m 7s
# 687:	total: 35.1s	remaining: 1m 6s
# 688:	total: 35.2s	remaining: 1m 6s
# 689:	total: 35.2s	remaining: 1m 6s
# 690:	total: 35.2s	remaining: 1m 6s
# 691:	total: 35.3s	remaining: 1m 6s
# 692:	total: 35.3s	remaining: 1m 6s
# 693:	total: 35.4s	remaining: 1m 6s
# 694:	total: 35.4s	remaining: 1m 6s
# 695:	total: 35.5s	remaining: 1m 6s
# 696:	total: 35.5s	remaining: 1m 6s
# 697:	total: 35.6s	remaining: 1m 6s
# 698:	total: 35.6s	remaining: 1m 6s
# 699:	total: 35.6s	remaining: 1m 6s
# 700:	total: 35.7s	remaining: 1m 6s
# 701:	total: 35.7s	remaining: 1m 6s
# 702:	total: 35.8s	remaining: 1m 6s
# 703:	total: 35.8s	remaining: 1m 5s
# 704:	total: 35.9s	remaining: 1m 5s
# 705:	total: 35.9s	remaining: 1m 5s
# 706:	total: 36s	remaining: 1m 5s
# 707:	total: 36s	remaining: 1m 5s
# 708:	total: 36s	remaining: 1m 5s
# 709:	total: 36.1s	remaining: 1m 5s
# 710:	total: 36.1s	remaining: 1m 5s
# 711:	total: 36.2s	remaining: 1m 5s
# 712:	total: 36.2s	remaining: 1m 5s
# 713:	total: 36.3s	remaining: 1m 5s
# 714:	total: 36.3s	remaining: 1m 5s
# 715:	total: 36.4s	remaining: 1m 5s
# 716:	total: 36.4s	remaining: 1m 5s
# 717:	total: 36.4s	remaining: 1m 5s
# 718:	total: 36.5s	remaining: 1m 5s
# 719:	total: 36.5s	remaining: 1m 4s
# 720:	total: 36.6s	remaining: 1m 4s
# 721:	total: 36.6s	remaining: 1m 4s
# 722:	total: 36.7s	remaining: 1m 4s
# 723:	total: 36.7s	remaining: 1m 4s
# 724:	total: 36.8s	remaining: 1m 4s
# 725:	total: 36.8s	remaining: 1m 4s
# 726:	total: 36.8s	remaining: 1m 4s
# 727:	total: 36.9s	remaining: 1m 4s
# 728:	total: 36.9s	remaining: 1m 4s
# 729:	total: 37s	remaining: 1m 4s
# 730:	total: 37s	remaining: 1m 4s
# 731:	total: 37s	remaining: 1m 4s
# 732:	total: 37.1s	remaining: 1m 4s
# 733:	total: 37.1s	remaining: 1m 4s
# 734:	total: 37.2s	remaining: 1m 3s
# 735:	total: 37.2s	remaining: 1m 3s
# 736:	total: 37.3s	remaining: 1m 3s
# 737:	total: 37.3s	remaining: 1m 3s
# 738:	total: 37.3s	remaining: 1m 3s
# 739:	total: 37.4s	remaining: 1m 3s
# 740:	total: 37.4s	remaining: 1m 3s
# 741:	total: 37.5s	remaining: 1m 3s
# 742:	total: 37.5s	remaining: 1m 3s
# 743:	total: 37.6s	remaining: 1m 3s
# 744:	total: 37.6s	remaining: 1m 3s
# 745:	total: 37.7s	remaining: 1m 3s
# 746:	total: 37.7s	remaining: 1m 3s
# 747:	total: 37.7s	remaining: 1m 3s
# 748:	total: 37.8s	remaining: 1m 3s
# 749:	total: 37.8s	remaining: 1m 3s
# 750:	total: 37.9s	remaining: 1m 2s
# 751:	total: 37.9s	remaining: 1m 2s
# 752:	total: 37.9s	remaining: 1m 2s
# 753:	total: 38s	remaining: 1m 2s
# 754:	total: 38s	remaining: 1m 2s
# 755:	total: 38.1s	remaining: 1m 2s
# 756:	total: 38.1s	remaining: 1m 2s
# 757:	total: 38.2s	remaining: 1m 2s
# 758:	total: 38.2s	remaining: 1m 2s
# 759:	total: 38.2s	remaining: 1m 2s
# 760:	total: 38.3s	remaining: 1m 2s
# 761:	total: 38.3s	remaining: 1m 2s
# 762:	total: 38.4s	remaining: 1m 2s
# 763:	total: 38.4s	remaining: 1m 2s
# 764:	total: 38.5s	remaining: 1m 2s
# 765:	total: 38.5s	remaining: 1m 2s
# 766:	total: 38.6s	remaining: 1m 1s
# 767:	total: 38.6s	remaining: 1m 1s
# 768:	total: 38.6s	remaining: 1m 1s
# 769:	total: 38.7s	remaining: 1m 1s
# 770:	total: 38.7s	remaining: 1m 1s
# 771:	total: 38.8s	remaining: 1m 1s
# 772:	total: 38.9s	remaining: 1m 1s
# 773:	total: 39s	remaining: 1m 1s
# 774:	total: 39s	remaining: 1m 1s
# 775:	total: 39.1s	remaining: 1m 1s
# 776:	total: 39.2s	remaining: 1m 1s
# 777:	total: 39.3s	remaining: 1m 1s
# 778:	total: 39.4s	remaining: 1m 1s
# 779:	total: 39.5s	remaining: 1m 1s
# 780:	total: 39.6s	remaining: 1m 1s
# 781:	total: 39.7s	remaining: 1m 1s
# 782:	total: 39.8s	remaining: 1m 1s
# 783:	total: 39.9s	remaining: 1m 1s
# 784:	total: 40s	remaining: 1m 1s
# 785:	total: 40.1s	remaining: 1m 1s
# 786:	total: 40.2s	remaining: 1m 1s
# 787:	total: 40.3s	remaining: 1m 1s
# 788:	total: 40.3s	remaining: 1m 1s
# 789:	total: 40.4s	remaining: 1m 1s
# 790:	total: 40.5s	remaining: 1m 1s
# 791:	total: 40.6s	remaining: 1m 1s
# 792:	total: 40.7s	remaining: 1m 1s
# 793:	total: 40.8s	remaining: 1m 1s
# 794:	total: 40.8s	remaining: 1m 1s
# 795:	total: 40.9s	remaining: 1m 1s
# 796:	total: 41s	remaining: 1m 1s
# 797:	total: 41.1s	remaining: 1m 1s
# 798:	total: 41.2s	remaining: 1m 1s
# 799:	total: 41.2s	remaining: 1m 1s
# 800:	total: 41.3s	remaining: 1m 1s
# 801:	total: 41.4s	remaining: 1m 1s
# 802:	total: 41.5s	remaining: 1m 1s
# 803:	total: 41.6s	remaining: 1m 1s
# 804:	total: 41.6s	remaining: 1m 1s
# 805:	total: 41.7s	remaining: 1m 1s
# 806:	total: 41.8s	remaining: 1m 1s
# 807:	total: 41.9s	remaining: 1m 1s
# 808:	total: 42s	remaining: 1m 1s
# 809:	total: 42.1s	remaining: 1m 1s
# 810:	total: 42.2s	remaining: 1m 1s
# 811:	total: 42.3s	remaining: 1m 1s
# 812:	total: 42.4s	remaining: 1m 1s
# 813:	total: 42.5s	remaining: 1m 1s
# 814:	total: 42.5s	remaining: 1m 1s
# 815:	total: 42.6s	remaining: 1m 1s
# 816:	total: 42.7s	remaining: 1m 1s
# 817:	total: 42.8s	remaining: 1m 1s
# 818:	total: 42.9s	remaining: 1m 1s
# 819:	total: 43s	remaining: 1m 1s
# 820:	total: 43.1s	remaining: 1m 1s
# 821:	total: 43.1s	remaining: 1m 1s
# 822:	total: 43.2s	remaining: 1m 1s
# 823:	total: 43.2s	remaining: 1m 1s
# 824:	total: 43.3s	remaining: 1m 1s
# 825:	total: 43.3s	remaining: 1m 1s
# 826:	total: 43.4s	remaining: 1m 1s
# 827:	total: 43.4s	remaining: 1m 1s
# 828:	total: 43.4s	remaining: 1m 1s
# 829:	total: 43.5s	remaining: 1m 1s
# 830:	total: 43.5s	remaining: 1m 1s
# 831:	total: 43.6s	remaining: 1m 1s
# 832:	total: 43.6s	remaining: 1m 1s
# 833:	total: 43.6s	remaining: 1m 1s
# 834:	total: 43.7s	remaining: 1m
# 835:	total: 43.7s	remaining: 1m
# 836:	total: 43.8s	remaining: 1m
# 837:	total: 43.8s	remaining: 1m
# 838:	total: 43.9s	remaining: 1m
# 839:	total: 43.9s	remaining: 1m
# 840:	total: 44s	remaining: 1m
# 841:	total: 44s	remaining: 1m
# 842:	total: 44s	remaining: 1m
# 843:	total: 44.1s	remaining: 1m
# 844:	total: 44.1s	remaining: 1m
# 845:	total: 44.2s	remaining: 1m
# 846:	total: 44.2s	remaining: 1m
# 847:	total: 44.3s	remaining: 1m
# 848:	total: 44.3s	remaining: 1m
# 849:	total: 44.4s	remaining: 1m
# 850:	total: 44.4s	remaining: 59.9s
# 851:	total: 44.4s	remaining: 59.9s
# 852:	total: 44.5s	remaining: 59.8s
# 853:	total: 44.5s	remaining: 59.8s
# 854:	total: 44.6s	remaining: 59.7s
# 855:	total: 44.6s	remaining: 59.6s
# 856:	total: 44.6s	remaining: 59.5s
# 857:	total: 44.7s	remaining: 59.5s
# 858:	total: 44.7s	remaining: 59.4s
# 859:	total: 44.8s	remaining: 59.4s
# 860:	total: 44.8s	remaining: 59.3s
# 861:	total: 44.9s	remaining: 59.3s
# 862:	total: 44.9s	remaining: 59.2s
# 863:	total: 45s	remaining: 59.1s
# 864:	total: 45s	remaining: 59.1s
# 865:	total: 45s	remaining: 59s
# 866:	total: 45.1s	remaining: 58.9s
# 867:	total: 45.1s	remaining: 58.9s
# 868:	total: 45.2s	remaining: 58.8s
# 869:	total: 45.2s	remaining: 58.7s
# 870:	total: 45.3s	remaining: 58.7s
# 871:	total: 45.3s	remaining: 58.6s
# 872:	total: 45.4s	remaining: 58.5s
# 873:	total: 45.4s	remaining: 58.5s
# 874:	total: 45.4s	remaining: 58.4s
# 875:	total: 45.5s	remaining: 58.3s
# 876:	total: 45.5s	remaining: 58.3s
# 877:	total: 45.6s	remaining: 58.2s
# 878:	total: 45.6s	remaining: 58.1s
# 879:	total: 45.6s	remaining: 58.1s
# 880:	total: 45.7s	remaining: 58s
# 881:	total: 45.7s	remaining: 58s
# 882:	total: 45.8s	remaining: 57.9s
# 883:	total: 45.8s	remaining: 57.8s
# 884:	total: 45.9s	remaining: 57.8s
# 885:	total: 45.9s	remaining: 57.7s
# 886:	total: 45.9s	remaining: 57.7s
# 887:	total: 46s	remaining: 57.6s
# 888:	total: 46s	remaining: 57.5s
# 889:	total: 46.1s	remaining: 57.5s
# 890:	total: 46.1s	remaining: 57.4s
# 891:	total: 46.2s	remaining: 57.3s
# 892:	total: 46.2s	remaining: 57.3s
# 893:	total: 46.2s	remaining: 57.2s
# 894:	total: 46.3s	remaining: 57.1s
# 895:	total: 46.3s	remaining: 57.1s
# 896:	total: 46.4s	remaining: 57s
# 897:	total: 46.4s	remaining: 57s
# 898:	total: 46.5s	remaining: 56.9s
# 899:	total: 46.5s	remaining: 56.8s
# 900:	total: 46.5s	remaining: 56.8s
# 901:	total: 46.6s	remaining: 56.7s
# 902:	total: 46.6s	remaining: 56.6s
# 903:	total: 46.7s	remaining: 56.6s
# 904:	total: 46.7s	remaining: 56.5s
# 905:	total: 46.7s	remaining: 56.4s
# 906:	total: 46.8s	remaining: 56.4s
# 907:	total: 46.8s	remaining: 56.3s
# 908:	total: 46.9s	remaining: 56.3s
# 909:	total: 46.9s	remaining: 56.2s
# 910:	total: 47s	remaining: 56.1s
# 911:	total: 47s	remaining: 56.1s
# 912:	total: 47.1s	remaining: 56s
# 913:	total: 47.1s	remaining: 56s
# 914:	total: 47.1s	remaining: 55.9s
# 915:	total: 47.2s	remaining: 55.8s
# 916:	total: 47.2s	remaining: 55.8s
# 917:	total: 47.3s	remaining: 55.7s
# 918:	total: 47.3s	remaining: 55.7s
# 919:	total: 47.3s	remaining: 55.6s
# 920:	total: 47.4s	remaining: 55.5s
# 921:	total: 47.4s	remaining: 55.5s
# 922:	total: 47.5s	remaining: 55.4s
# 923:	total: 47.5s	remaining: 55.3s
# 924:	total: 47.6s	remaining: 55.3s
# 925:	total: 47.6s	remaining: 55.2s
# 926:	total: 47.6s	remaining: 55.1s
# 927:	total: 47.7s	remaining: 55.1s
# 928:	total: 47.7s	remaining: 55s
# 929:	total: 47.8s	remaining: 55s
# 930:	total: 47.8s	remaining: 54.9s
# 931:	total: 47.9s	remaining: 54.9s
# 932:	total: 47.9s	remaining: 54.8s
# 933:	total: 48s	remaining: 54.7s
# 934:	total: 48s	remaining: 54.7s
# 935:	total: 48s	remaining: 54.6s
# 936:	total: 48.1s	remaining: 54.6s
# 937:	total: 48.1s	remaining: 54.5s
# 938:	total: 48.2s	remaining: 54.4s
# 939:	total: 48.2s	remaining: 54.4s
# 940:	total: 48.3s	remaining: 54.3s
# 941:	total: 48.3s	remaining: 54.3s
# 942:	total: 48.3s	remaining: 54.2s
# 943:	total: 48.4s	remaining: 54.1s
# 944:	total: 48.4s	remaining: 54.1s
# 945:	total: 48.5s	remaining: 54s
# 946:	total: 48.5s	remaining: 53.9s
# 947:	total: 48.6s	remaining: 53.9s
# 948:	total: 48.6s	remaining: 53.8s
# 949:	total: 48.6s	remaining: 53.8s
# 950:	total: 48.7s	remaining: 53.7s
# 951:	total: 48.7s	remaining: 53.6s
# 952:	total: 48.8s	remaining: 53.6s
# 953:	total: 48.8s	remaining: 53.5s
# 954:	total: 48.9s	remaining: 53.5s
# 955:	total: 48.9s	remaining: 53.4s
# 956:	total: 49s	remaining: 53.4s
# 957:	total: 49s	remaining: 53.3s
# 958:	total: 49s	remaining: 53.2s
# 959:	total: 49.1s	remaining: 53.2s
# 960:	total: 49.1s	remaining: 53.1s
# 961:	total: 49.2s	remaining: 53.1s
# 962:	total: 49.2s	remaining: 53s
# 963:	total: 49.3s	remaining: 52.9s
# 964:	total: 49.3s	remaining: 52.9s
# 965:	total: 49.4s	remaining: 52.8s
# 966:	total: 49.4s	remaining: 52.8s
# 967:	total: 49.4s	remaining: 52.7s
# 968:	total: 49.5s	remaining: 52.7s
# 969:	total: 49.5s	remaining: 52.6s
# 970:	total: 49.6s	remaining: 52.5s
# 971:	total: 49.6s	remaining: 52.5s
# 972:	total: 49.7s	remaining: 52.4s
# 973:	total: 49.7s	remaining: 52.4s
# 974:	total: 49.7s	remaining: 52.3s
# 975:	total: 49.8s	remaining: 52.2s
# 976:	total: 49.8s	remaining: 52.2s
# 977:	total: 49.9s	remaining: 52.1s
# 978:	total: 49.9s	remaining: 52.1s
# 979:	total: 50s	remaining: 52s
# 980:	total: 50s	remaining: 51.9s
# 981:	total: 50s	remaining: 51.9s
# 982:	total: 50.1s	remaining: 51.8s
# 983:	total: 50.1s	remaining: 51.8s
# 984:	total: 50.2s	remaining: 51.7s
# 985:	total: 50.2s	remaining: 51.6s
# 986:	total: 50.3s	remaining: 51.6s
# 987:	total: 50.3s	remaining: 51.5s
# 988:	total: 50.4s	remaining: 51.5s
# 989:	total: 50.4s	remaining: 51.4s
# 990:	total: 50.4s	remaining: 51.4s
# 991:	total: 50.5s	remaining: 51.3s
# 992:	total: 50.5s	remaining: 51.2s
# 993:	total: 50.6s	remaining: 51.2s
# 994:	total: 50.6s	remaining: 51.1s
# 995:	total: 50.7s	remaining: 51.1s
# 996:	total: 50.7s	remaining: 51s
# 997:	total: 50.7s	remaining: 50.9s
# 998:	total: 50.8s	remaining: 50.9s
# 999:	total: 50.8s	remaining: 50.8s
# 1000:	total: 50.9s	remaining: 50.8s
# 1001:	total: 50.9s	remaining: 50.7s
# 1002:	total: 51s	remaining: 50.7s
# 1003:	total: 51s	remaining: 50.6s
# 1004:	total: 51s	remaining: 50.5s
# 1005:	total: 51.1s	remaining: 50.5s
# 1006:	total: 51.1s	remaining: 50.4s
# 1007:	total: 51.2s	remaining: 50.4s
# 1008:	total: 51.2s	remaining: 50.3s
# 1009:	total: 51.3s	remaining: 50.2s
# 1010:	total: 51.3s	remaining: 50.2s
# 1011:	total: 51.3s	remaining: 50.1s
# 1012:	total: 51.4s	remaining: 50.1s
# 1013:	total: 51.4s	remaining: 50s
# 1014:	total: 51.5s	remaining: 50s
# 1015:	total: 51.5s	remaining: 49.9s
# 1016:	total: 51.6s	remaining: 49.8s
# 1017:	total: 51.6s	remaining: 49.8s
# 1018:	total: 51.6s	remaining: 49.7s
# 1019:	total: 51.7s	remaining: 49.7s
# 1020:	total: 51.7s	remaining: 49.6s
# 1021:	total: 51.8s	remaining: 49.5s
# 1022:	total: 51.8s	remaining: 49.5s
# 1023:	total: 51.9s	remaining: 49.4s
# 1024:	total: 51.9s	remaining: 49.4s
# 1025:	total: 52s	remaining: 49.3s
# 1026:	total: 52s	remaining: 49.3s
# 1027:	total: 52.1s	remaining: 49.2s
# 1028:	total: 52.1s	remaining: 49.2s
# 1029:	total: 52.1s	remaining: 49.1s
# 1030:	total: 52.2s	remaining: 49s
# 1031:	total: 52.2s	remaining: 49s
# 1032:	total: 52.3s	remaining: 48.9s
# 1033:	total: 52.3s	remaining: 48.9s
# 1034:	total: 52.4s	remaining: 48.8s
# 1035:	total: 52.4s	remaining: 48.7s
# 1036:	total: 52.4s	remaining: 48.7s
# 1037:	total: 52.5s	remaining: 48.6s
# 1038:	total: 52.5s	remaining: 48.6s
# 1039:	total: 52.6s	remaining: 48.5s
# 1040:	total: 52.6s	remaining: 48.5s
# 1041:	total: 52.6s	remaining: 48.4s
# 1042:	total: 52.7s	remaining: 48.3s
# 1043:	total: 52.7s	remaining: 48.3s
# 1044:	total: 52.8s	remaining: 48.2s
# 1045:	total: 52.8s	remaining: 48.2s
# 1046:	total: 52.9s	remaining: 48.1s
# 1047:	total: 52.9s	remaining: 48s
# 1048:	total: 52.9s	remaining: 48s
# 1049:	total: 53s	remaining: 47.9s
# 1050:	total: 53s	remaining: 47.9s
# 1051:	total: 53.1s	remaining: 47.9s
# 1052:	total: 53.2s	remaining: 47.8s
# 1053:	total: 53.3s	remaining: 47.8s
# 1054:	total: 53.4s	remaining: 47.8s
# 1055:	total: 53.4s	remaining: 47.8s
# 1056:	total: 53.5s	remaining: 47.8s
# 1057:	total: 53.6s	remaining: 47.8s
# 1058:	total: 53.7s	remaining: 47.7s
# 1059:	total: 53.8s	remaining: 47.7s
# 1060:	total: 53.9s	remaining: 47.7s
# 1061:	total: 54s	remaining: 47.7s
# 1062:	total: 54.1s	remaining: 47.7s
# 1063:	total: 54.2s	remaining: 47.6s
# 1064:	total: 54.3s	remaining: 47.6s
# 1065:	total: 54.3s	remaining: 47.6s
# 1066:	total: 54.4s	remaining: 47.6s
# 1067:	total: 54.5s	remaining: 47.6s
# 1068:	total: 54.6s	remaining: 47.5s
# 1069:	total: 54.7s	remaining: 47.5s
# 1070:	total: 54.8s	remaining: 47.5s
# 1071:	total: 54.9s	remaining: 47.5s
# 1072:	total: 55s	remaining: 47.5s
# 1073:	total: 55s	remaining: 47.5s
# 1074:	total: 55.1s	remaining: 47.4s
# 1075:	total: 55.2s	remaining: 47.4s
# 1076:	total: 55.3s	remaining: 47.4s
# 1077:	total: 55.4s	remaining: 47.4s
# 1078:	total: 55.5s	remaining: 47.4s
# 1079:	total: 55.6s	remaining: 47.3s
# 1080:	total: 55.6s	remaining: 47.3s
# 1081:	total: 55.7s	remaining: 47.3s
# 1082:	total: 55.8s	remaining: 47.3s
# 1083:	total: 55.9s	remaining: 47.2s
# 1084:	total: 56s	remaining: 47.2s
# 1085:	total: 56s	remaining: 47.2s
# 1086:	total: 56.1s	remaining: 47.1s
# 1087:	total: 56.2s	remaining: 47.1s
# 1088:	total: 56.3s	remaining: 47.1s
# 1089:	total: 56.4s	remaining: 47s
# 1090:	total: 56.4s	remaining: 47s
# 1091:	total: 56.5s	remaining: 47s
# 1092:	total: 56.6s	remaining: 47s
# 1093:	total: 56.7s	remaining: 47s
# 1094:	total: 56.8s	remaining: 47s
# 1095:	total: 56.9s	remaining: 46.9s
# 1096:	total: 57s	remaining: 46.9s
# 1097:	total: 57.1s	remaining: 46.9s
# 1098:	total: 57.2s	remaining: 46.9s
# 1099:	total: 57.3s	remaining: 46.9s
# 1100:	total: 57.4s	remaining: 46.8s
# 1101:	total: 57.4s	remaining: 46.8s
# 1102:	total: 57.4s	remaining: 46.7s
# 1103:	total: 57.5s	remaining: 46.7s
# 1104:	total: 57.5s	remaining: 46.6s
# 1105:	total: 57.6s	remaining: 46.5s
# 1106:	total: 57.6s	remaining: 46.5s
# 1107:	total: 57.7s	remaining: 46.4s
# 1108:	total: 57.7s	remaining: 46.4s
# 1109:	total: 57.7s	remaining: 46.3s
# 1110:	total: 57.8s	remaining: 46.2s
# 1111:	total: 57.8s	remaining: 46.2s
# 1112:	total: 57.9s	remaining: 46.1s
# 1113:	total: 57.9s	remaining: 46.1s
# 1114:	total: 58s	remaining: 46s
# 1115:	total: 58s	remaining: 45.9s
# 1116:	total: 58s	remaining: 45.9s
# 1117:	total: 58.1s	remaining: 45.8s
# 1118:	total: 58.1s	remaining: 45.8s
# 1119:	total: 58.2s	remaining: 45.7s
# 1120:	total: 58.2s	remaining: 45.7s
# 1121:	total: 58.3s	remaining: 45.6s
# 1122:	total: 58.3s	remaining: 45.5s
# 1123:	total: 58.4s	remaining: 45.5s
# 1124:	total: 58.4s	remaining: 45.4s
# 1125:	total: 58.4s	remaining: 45.4s
# 1126:	total: 58.5s	remaining: 45.3s
# 1127:	total: 58.5s	remaining: 45.2s
# 1128:	total: 58.6s	remaining: 45.2s
# 1129:	total: 58.6s	remaining: 45.1s
# 1130:	total: 58.7s	remaining: 45.1s
# 1131:	total: 58.7s	remaining: 45s
# 1132:	total: 58.7s	remaining: 44.9s
# 1133:	total: 58.8s	remaining: 44.9s
# 1134:	total: 58.8s	remaining: 44.8s
# 1135:	total: 58.9s	remaining: 44.8s
# 1136:	total: 58.9s	remaining: 44.7s
# 1137:	total: 59s	remaining: 44.7s
# 1138:	total: 59s	remaining: 44.6s
# 1139:	total: 59s	remaining: 44.5s
# 1140:	total: 59.1s	remaining: 44.5s
# 1141:	total: 59.1s	remaining: 44.4s
# 1142:	total: 59.2s	remaining: 44.4s
# 1143:	total: 59.2s	remaining: 44.3s
# 1144:	total: 59.3s	remaining: 44.3s
# 1145:	total: 59.3s	remaining: 44.2s
# 1146:	total: 59.4s	remaining: 44.1s
# 1147:	total: 59.4s	remaining: 44.1s
# 1148:	total: 59.5s	remaining: 44s
# 1149:	total: 59.5s	remaining: 44s
# 1150:	total: 59.5s	remaining: 43.9s
# 1151:	total: 59.6s	remaining: 43.9s
# 1152:	total: 59.6s	remaining: 43.8s
# 1153:	total: 59.7s	remaining: 43.7s
# 1154:	total: 59.7s	remaining: 43.7s
# 1155:	total: 59.8s	remaining: 43.6s
# 1156:	total: 59.8s	remaining: 43.6s
# 1157:	total: 59.8s	remaining: 43.5s
# 1158:	total: 59.9s	remaining: 43.4s
# 1159:	total: 59.9s	remaining: 43.4s
# 1160:	total: 60s	remaining: 43.3s
# 1161:	total: 1m	remaining: 43.3s
# 1162:	total: 1m	remaining: 43.2s
# 1163:	total: 1m	remaining: 43.2s
# 1164:	total: 1m	remaining: 43.1s
# 1165:	total: 1m	remaining: 43.1s
# 1166:	total: 1m	remaining: 43s
# 1167:	total: 1m	remaining: 43s
# 1168:	total: 1m	remaining: 42.9s
# 1169:	total: 1m	remaining: 42.8s
# 1170:	total: 1m	remaining: 42.8s
# 1171:	total: 1m	remaining: 42.7s
# 1172:	total: 1m	remaining: 42.7s
# 1173:	total: 1m	remaining: 42.6s
# 1174:	total: 1m	remaining: 42.6s
# 1175:	total: 1m	remaining: 42.5s
# 1176:	total: 1m	remaining: 42.4s
# 1177:	total: 1m	remaining: 42.4s
# 1178:	total: 1m	remaining: 42.3s
# 1179:	total: 1m	remaining: 42.3s
# 1180:	total: 1m	remaining: 42.2s
# 1181:	total: 1m	remaining: 42.1s
# 1182:	total: 1m	remaining: 42.1s
# 1183:	total: 1m	remaining: 42s
# 1184:	total: 1m 1s	remaining: 42s
# 1185:	total: 1m 1s	remaining: 41.9s
# 1186:	total: 1m 1s	remaining: 41.9s
# 1187:	total: 1m 1s	remaining: 41.8s
# 1188:	total: 1m 1s	remaining: 41.7s
# 1189:	total: 1m 1s	remaining: 41.7s
# 1190:	total: 1m 1s	remaining: 41.6s
# 1191:	total: 1m 1s	remaining: 41.6s
# 1192:	total: 1m 1s	remaining: 41.5s
# 1193:	total: 1m 1s	remaining: 41.5s
# 1194:	total: 1m 1s	remaining: 41.4s
# 1195:	total: 1m 1s	remaining: 41.4s
# 1196:	total: 1m 1s	remaining: 41.3s
# 1197:	total: 1m 1s	remaining: 41.2s
# 1198:	total: 1m 1s	remaining: 41.2s
# 1199:	total: 1m 1s	remaining: 41.1s
# 1200:	total: 1m 1s	remaining: 41.1s
# 1201:	total: 1m 1s	remaining: 41s
# 1202:	total: 1m 1s	remaining: 41s
# 1203:	total: 1m 1s	remaining: 40.9s
# 1204:	total: 1m 1s	remaining: 40.8s
# 1205:	total: 1m 1s	remaining: 40.8s
# 1206:	total: 1m 1s	remaining: 40.7s
# 1207:	total: 1m 2s	remaining: 40.7s
# 1208:	total: 1m 2s	remaining: 40.6s
# 1209:	total: 1m 2s	remaining: 40.6s
# 1210:	total: 1m 2s	remaining: 40.5s
# 1211:	total: 1m 2s	remaining: 40.4s
# 1212:	total: 1m 2s	remaining: 40.4s
# 1213:	total: 1m 2s	remaining: 40.3s
# 1214:	total: 1m 2s	remaining: 40.3s
# 1215:	total: 1m 2s	remaining: 40.2s
# 1216:	total: 1m 2s	remaining: 40.2s
# 1217:	total: 1m 2s	remaining: 40.1s
# 1218:	total: 1m 2s	remaining: 40.1s
# 1219:	total: 1m 2s	remaining: 40s
# 1220:	total: 1m 2s	remaining: 39.9s
# 1221:	total: 1m 2s	remaining: 39.9s
# 1222:	total: 1m 2s	remaining: 39.8s
# 1223:	total: 1m 2s	remaining: 39.8s
# 1224:	total: 1m 2s	remaining: 39.7s
# 1225:	total: 1m 2s	remaining: 39.7s
# 1226:	total: 1m 2s	remaining: 39.6s
# 1227:	total: 1m 2s	remaining: 39.5s
# 1228:	total: 1m 2s	remaining: 39.5s
# 1229:	total: 1m 2s	remaining: 39.4s
# 1230:	total: 1m 3s	remaining: 39.4s
# 1231:	total: 1m 3s	remaining: 39.3s
# 1232:	total: 1m 3s	remaining: 39.3s
# 1233:	total: 1m 3s	remaining: 39.2s
# 1234:	total: 1m 3s	remaining: 39.1s
# 1235:	total: 1m 3s	remaining: 39.1s
# 1236:	total: 1m 3s	remaining: 39s
# 1237:	total: 1m 3s	remaining: 39s
# 1238:	total: 1m 3s	remaining: 38.9s
# 1239:	total: 1m 3s	remaining: 38.9s
# 1240:	total: 1m 3s	remaining: 38.8s
# 1241:	total: 1m 3s	remaining: 38.7s
# 1242:	total: 1m 3s	remaining: 38.7s
# 1243:	total: 1m 3s	remaining: 38.6s
# 1244:	total: 1m 3s	remaining: 38.6s
# 1245:	total: 1m 3s	remaining: 38.5s
# 1246:	total: 1m 3s	remaining: 38.5s
# 1247:	total: 1m 3s	remaining: 38.4s
# 1248:	total: 1m 3s	remaining: 38.3s
# 1249:	total: 1m 3s	remaining: 38.3s
# 1250:	total: 1m 3s	remaining: 38.2s
# 1251:	total: 1m 3s	remaining: 38.2s
# 1252:	total: 1m 3s	remaining: 38.1s
# 1253:	total: 1m 3s	remaining: 38.1s
# 1254:	total: 1m 4s	remaining: 38s
# 1255:	total: 1m 4s	remaining: 38s
# 1256:	total: 1m 4s	remaining: 37.9s
# 1257:	total: 1m 4s	remaining: 37.8s
# 1258:	total: 1m 4s	remaining: 37.8s
# 1259:	total: 1m 4s	remaining: 37.7s
# 1260:	total: 1m 4s	remaining: 37.7s
# 1261:	total: 1m 4s	remaining: 37.6s
# 1262:	total: 1m 4s	remaining: 37.6s
# 1263:	total: 1m 4s	remaining: 37.5s
# 1264:	total: 1m 4s	remaining: 37.5s
# 1265:	total: 1m 4s	remaining: 37.4s
# 1266:	total: 1m 4s	remaining: 37.4s
# 1267:	total: 1m 4s	remaining: 37.3s
# 1268:	total: 1m 4s	remaining: 37.2s
# 1269:	total: 1m 4s	remaining: 37.2s
# 1270:	total: 1m 4s	remaining: 37.1s
# 1271:	total: 1m 4s	remaining: 37.1s
# 1272:	total: 1m 4s	remaining: 37s
# 1273:	total: 1m 4s	remaining: 37s
# 1274:	total: 1m 4s	remaining: 36.9s
# 1275:	total: 1m 4s	remaining: 36.9s
# 1276:	total: 1m 5s	remaining: 36.8s
# 1277:	total: 1m 5s	remaining: 36.7s
# 1278:	total: 1m 5s	remaining: 36.7s
# 1279:	total: 1m 5s	remaining: 36.6s
# 1280:	total: 1m 5s	remaining: 36.6s
# 1281:	total: 1m 5s	remaining: 36.5s
# 1282:	total: 1m 5s	remaining: 36.5s
# 1283:	total: 1m 5s	remaining: 36.4s
# 1284:	total: 1m 5s	remaining: 36.4s
# 1285:	total: 1m 5s	remaining: 36.3s
# 1286:	total: 1m 5s	remaining: 36.3s
# 1287:	total: 1m 5s	remaining: 36.2s
# 1288:	total: 1m 5s	remaining: 36.1s
# 1289:	total: 1m 5s	remaining: 36.1s
# 1290:	total: 1m 5s	remaining: 36s
# 1291:	total: 1m 5s	remaining: 36s
# 1292:	total: 1m 5s	remaining: 35.9s
# 1293:	total: 1m 5s	remaining: 35.9s
# 1294:	total: 1m 5s	remaining: 35.8s
# 1295:	total: 1m 5s	remaining: 35.8s
# 1296:	total: 1m 5s	remaining: 35.7s
# 1297:	total: 1m 5s	remaining: 35.6s
# 1298:	total: 1m 5s	remaining: 35.6s
# 1299:	total: 1m 6s	remaining: 35.5s
# 1300:	total: 1m 6s	remaining: 35.5s
# 1301:	total: 1m 6s	remaining: 35.4s
# 1302:	total: 1m 6s	remaining: 35.4s
# 1303:	total: 1m 6s	remaining: 35.3s
# 1304:	total: 1m 6s	remaining: 35.3s
# 1305:	total: 1m 6s	remaining: 35.2s
# 1306:	total: 1m 6s	remaining: 35.2s
# 1307:	total: 1m 6s	remaining: 35.1s
# 1308:	total: 1m 6s	remaining: 35.1s
# 1309:	total: 1m 6s	remaining: 35s
# 1310:	total: 1m 6s	remaining: 34.9s
# 1311:	total: 1m 6s	remaining: 34.9s
# 1312:	total: 1m 6s	remaining: 34.8s
# 1313:	total: 1m 6s	remaining: 34.8s
# 1314:	total: 1m 6s	remaining: 34.7s
# 1315:	total: 1m 6s	remaining: 34.7s
# 1316:	total: 1m 6s	remaining: 34.6s
# 1317:	total: 1m 6s	remaining: 34.6s
# 1318:	total: 1m 6s	remaining: 34.5s
# 1319:	total: 1m 6s	remaining: 34.4s
# 1320:	total: 1m 6s	remaining: 34.4s
# 1321:	total: 1m 6s	remaining: 34.3s
# 1322:	total: 1m 6s	remaining: 34.3s
# 1323:	total: 1m 7s	remaining: 34.2s
# 1324:	total: 1m 7s	remaining: 34.2s
# 1325:	total: 1m 7s	remaining: 34.1s
# 1326:	total: 1m 7s	remaining: 34.1s
# 1327:	total: 1m 7s	remaining: 34s
# 1328:	total: 1m 7s	remaining: 34s
# 1329:	total: 1m 7s	remaining: 33.9s
# 1330:	total: 1m 7s	remaining: 33.9s
# 1331:	total: 1m 7s	remaining: 33.8s
# 1332:	total: 1m 7s	remaining: 33.8s
# 1333:	total: 1m 7s	remaining: 33.7s
# 1334:	total: 1m 7s	remaining: 33.7s
# 1335:	total: 1m 7s	remaining: 33.7s
# 1336:	total: 1m 7s	remaining: 33.6s
# 1337:	total: 1m 7s	remaining: 33.6s
# 1338:	total: 1m 8s	remaining: 33.6s
# 1339:	total: 1m 8s	remaining: 33.6s
# 1340:	total: 1m 8s	remaining: 33.5s
# 1341:	total: 1m 8s	remaining: 33.5s
# 1342:	total: 1m 8s	remaining: 33.5s
# 1343:	total: 1m 8s	remaining: 33.4s
# 1344:	total: 1m 8s	remaining: 33.4s
# 1345:	total: 1m 8s	remaining: 33.4s
# 1346:	total: 1m 8s	remaining: 33.3s
# 1347:	total: 1m 8s	remaining: 33.3s
# 1348:	total: 1m 8s	remaining: 33.3s
# 1349:	total: 1m 9s	remaining: 33.2s
# 1350:	total: 1m 9s	remaining: 33.2s
# 1351:	total: 1m 9s	remaining: 33.2s
# 1352:	total: 1m 9s	remaining: 33.1s
# 1353:	total: 1m 9s	remaining: 33.1s
# 1354:	total: 1m 9s	remaining: 33.1s
# 1355:	total: 1m 9s	remaining: 33s
# 1356:	total: 1m 9s	remaining: 33s
# 1357:	total: 1m 9s	remaining: 33s
# ...
# 1566:	total: 1m 19s	remaining: 22s
# 1567:	total: 1m 19s	remaining: 22s
# 1568:	total: 1m 19s	remaining: 21.9s
# 1569:	total: 1m 19s	remaining: 21.9s
# 1570:	total: 1m 19s	remaining: 21.8s
# 1571:	total: 1m 19s	remaining: 21.8s
# 1572:	total: 1m 19s	remaining: 21.7s
# 1573:	total: 1m 20s	remaining: 21.7s
# 1574:	total: 1m 20s	remaining: 21.6s
# 1575:	total: 1m 20s	remaining: 21.6s
# 1576:	total: 1m 20s	remaining: 21.5s
# 1577:	total: 1m 20s	remaining: 21.4s
# 1578:	total: 1m 20s	remaining: 21.4s
# 1579:	total: 1m 20s	remaining: 21.3s
# 1580:	total: 1m 20s	remaining: 21.3s
# 1581:	total: 1m 20s	remaining: 21.2s
# 1582:	total: 1m 20s	remaining: 21.2s
# 1583:	total: 1m 20s	remaining: 21.1s
# 1584:	total: 1m 20s	remaining: 21.1s
# 1585:	total: 1m 20s	remaining: 21s
# 1586:	total: 1m 20s	remaining: 21s
# 1587:	total: 1m 20s	remaining: 20.9s
# 1588:	total: 1m 20s	remaining: 20.9s
# 1589:	total: 1m 20s	remaining: 20.8s
# 1590:	total: 1m 20s	remaining: 20.8s
# 1591:	total: 1m 20s	remaining: 20.7s
# 1592:	total: 1m 20s	remaining: 20.7s
# 1593:	total: 1m 20s	remaining: 20.6s
# 1594:	total: 1m 20s	remaining: 20.6s
# 1595:	total: 1m 20s	remaining: 20.5s
# 1596:	total: 1m 21s	remaining: 20.4s
# 1597:	total: 1m 21s	remaining: 20.4s
# 1598:	total: 1m 21s	remaining: 20.3s
# 1599:	total: 1m 21s	remaining: 20.3s
# 1600:	total: 1m 21s	remaining: 20.2s
# 1601:	total: 1m 21s	remaining: 20.2s
# 1602:	total: 1m 21s	remaining: 20.1s
# 1603:	total: 1m 21s	remaining: 20.1s
# 1604:	total: 1m 21s	remaining: 20s
# 1605:	total: 1m 21s	remaining: 20s
# 1606:	total: 1m 21s	remaining: 19.9s
# 1607:	total: 1m 21s	remaining: 19.9s
# 1608:	total: 1m 21s	remaining: 19.8s
# 1609:	total: 1m 21s	remaining: 19.8s
# 1610:	total: 1m 21s	remaining: 19.7s
# 1611:	total: 1m 21s	remaining: 19.7s
# 1612:	total: 1m 21s	remaining: 19.7s
# 1613:	total: 1m 22s	remaining: 19.6s
# 1614:	total: 1m 22s	remaining: 19.6s
# 1615:	total: 1m 22s	remaining: 19.5s
# 1616:	total: 1m 22s	remaining: 19.5s
# 1617:	total: 1m 22s	remaining: 19.5s
# 1618:	total: 1m 22s	remaining: 19.4s
# 1619:	total: 1m 22s	remaining: 19.4s
# 1620:	total: 1m 22s	remaining: 19.3s
# 1621:	total: 1m 22s	remaining: 19.3s
# 1622:	total: 1m 22s	remaining: 19.3s
# 1623:	total: 1m 22s	remaining: 19.2s
# 1624:	total: 1m 23s	remaining: 19.2s
# 1625:	total: 1m 23s	remaining: 19.1s
# 1626:	total: 1m 23s	remaining: 19.1s
# 1627:	total: 1m 23s	remaining: 19s
# 1628:	total: 1m 23s	remaining: 19s
# 1629:	total: 1m 23s	remaining: 19s
# 1630:	total: 1m 23s	remaining: 18.9s
# 1631:	total: 1m 23s	remaining: 18.9s
# 1632:	total: 1m 23s	remaining: 18.8s
# 1633:	total: 1m 23s	remaining: 18.8s
# 1634:	total: 1m 23s	remaining: 18.7s
# 1635:	total: 1m 24s	remaining: 18.7s
# 1636:	total: 1m 24s	remaining: 18.6s
# 1637:	total: 1m 24s	remaining: 18.6s
# 1638:	total: 1m 24s	remaining: 18.6s
# 1639:	total: 1m 24s	remaining: 18.5s
# 1640:	total: 1m 24s	remaining: 18.5s
# 1641:	total: 1m 24s	remaining: 18.4s
# 1642:	total: 1m 24s	remaining: 18.4s
# 1643:	total: 1m 24s	remaining: 18.3s
# 1644:	total: 1m 24s	remaining: 18.3s
# 1645:	total: 1m 24s	remaining: 18.3s
# 1646:	total: 1m 24s	remaining: 18.2s
# 1647:	total: 1m 24s	remaining: 18.2s
# 1648:	total: 1m 25s	remaining: 18.1s
# 1649:	total: 1m 25s	remaining: 18.1s
# 1650:	total: 1m 25s	remaining: 18s
# 1651:	total: 1m 25s	remaining: 18s
# 1652:	total: 1m 25s	remaining: 17.9s
# 1653:	total: 1m 25s	remaining: 17.9s
# 1654:	total: 1m 25s	remaining: 17.8s
# 1655:	total: 1m 25s	remaining: 17.8s
# 1656:	total: 1m 25s	remaining: 17.7s
# 1657:	total: 1m 25s	remaining: 17.7s
# 1658:	total: 1m 25s	remaining: 17.6s
# 1659:	total: 1m 25s	remaining: 17.6s
# 1660:	total: 1m 25s	remaining: 17.5s
# 1661:	total: 1m 25s	remaining: 17.5s
# 1662:	total: 1m 26s	remaining: 17.4s
# 1663:	total: 1m 26s	remaining: 17.4s
# 1664:	total: 1m 26s	remaining: 17.3s
# 1665:	total: 1m 26s	remaining: 17.3s
# 1666:	total: 1m 26s	remaining: 17.2s
# 1667:	total: 1m 26s	remaining: 17.2s
# 1668:	total: 1m 26s	remaining: 17.1s
# 1669:	total: 1m 26s	remaining: 17.1s
# 1670:	total: 1m 26s	remaining: 17s
# 1671:	total: 1m 26s	remaining: 17s
# 1672:	total: 1m 26s	remaining: 16.9s
# 1673:	total: 1m 26s	remaining: 16.8s
# 1674:	total: 1m 26s	remaining: 16.8s
# 1675:	total: 1m 26s	remaining: 16.7s
# 1676:	total: 1m 26s	remaining: 16.7s
# 1677:	total: 1m 26s	remaining: 16.6s
# 1678:	total: 1m 26s	remaining: 16.6s
# 1679:	total: 1m 26s	remaining: 16.5s
# 1680:	total: 1m 26s	remaining: 16.5s
# 1681:	total: 1m 26s	remaining: 16.4s
# 1682:	total: 1m 26s	remaining: 16.4s
# 1683:	total: 1m 26s	remaining: 16.3s
# 1684:	total: 1m 27s	remaining: 16.3s
# 1685:	total: 1m 27s	remaining: 16.2s
# 1686:	total: 1m 27s	remaining: 16.2s
# 1687:	total: 1m 27s	remaining: 16.1s
# 1688:	total: 1m 27s	remaining: 16.1s
# 1689:	total: 1m 27s	remaining: 16s
# 1690:	total: 1m 27s	remaining: 15.9s
# 1691:	total: 1m 27s	remaining: 15.9s
# 1692:	total: 1m 27s	remaining: 15.8s
# 1693:	total: 1m 27s	remaining: 15.8s
# 1694:	total: 1m 27s	remaining: 15.7s
# 1695:	total: 1m 27s	remaining: 15.7s
# 1696:	total: 1m 27s	remaining: 15.6s
# 1697:	total: 1m 27s	remaining: 15.6s
# 1698:	total: 1m 27s	remaining: 15.5s
# 1699:	total: 1m 27s	remaining: 15.5s
# 1700:	total: 1m 27s	remaining: 15.4s
# 1701:	total: 1m 27s	remaining: 15.4s
# 1702:	total: 1m 27s	remaining: 15.3s
# 1703:	total: 1m 27s	remaining: 15.3s
# 1704:	total: 1m 27s	remaining: 15.2s
# 1705:	total: 1m 27s	remaining: 15.2s
# 1706:	total: 1m 27s	remaining: 15.1s
# 1707:	total: 1m 28s	remaining: 15s
# 1708:	total: 1m 28s	remaining: 15s
# 1709:	total: 1m 28s	remaining: 14.9s
# 1710:	total: 1m 28s	remaining: 14.9s
# 1711:	total: 1m 28s	remaining: 14.8s
# 1712:	total: 1m 28s	remaining: 14.8s
# 1713:	total: 1m 28s	remaining: 14.7s
# 1714:	total: 1m 28s	remaining: 14.7s
# 1715:	total: 1m 28s	remaining: 14.6s
# 1716:	total: 1m 28s	remaining: 14.6s
# 1717:	total: 1m 28s	remaining: 14.5s
# 1718:	total: 1m 28s	remaining: 14.5s
# 1719:	total: 1m 28s	remaining: 14.4s
# 1720:	total: 1m 28s	remaining: 14.4s
# 1721:	total: 1m 28s	remaining: 14.3s
# 1722:	total: 1m 28s	remaining: 14.3s
# 1723:	total: 1m 28s	remaining: 14.2s
# 1724:	total: 1m 28s	remaining: 14.1s
# 1725:	total: 1m 28s	remaining: 14.1s
# 1726:	total: 1m 28s	remaining: 14s
# 1727:	total: 1m 28s	remaining: 14s
# 1728:	total: 1m 28s	remaining: 13.9s
# 1729:	total: 1m 28s	remaining: 13.9s
# 1730:	total: 1m 29s	remaining: 13.8s
# 1731:	total: 1m 29s	remaining: 13.8s
# 1732:	total: 1m 29s	remaining: 13.7s
# 1733:	total: 1m 29s	remaining: 13.7s
# 1734:	total: 1m 29s	remaining: 13.6s
# 1735:	total: 1m 29s	remaining: 13.6s
# 1736:	total: 1m 29s	remaining: 13.5s
# 1737:	total: 1m 29s	remaining: 13.5s
# 1738:	total: 1m 29s	remaining: 13.4s
# 1739:	total: 1m 29s	remaining: 13.4s
# 1740:	total: 1m 29s	remaining: 13.3s
# 1741:	total: 1m 29s	remaining: 13.3s
# 1742:	total: 1m 29s	remaining: 13.2s
# 1743:	total: 1m 29s	remaining: 13.2s
# 1744:	total: 1m 29s	remaining: 13.1s
# 1745:	total: 1m 29s	remaining: 13.1s
# 1746:	total: 1m 30s	remaining: 13s
# 1747:	total: 1m 30s	remaining: 13s
# 1748:	total: 1m 30s	remaining: 13s
# 1749:	total: 1m 30s	remaining: 12.9s
# 1750:	total: 1m 30s	remaining: 12.9s
# 1751:	total: 1m 30s	remaining: 12.8s
# 1752:	total: 1m 30s	remaining: 12.8s
# 1753:	total: 1m 30s	remaining: 12.7s
# 1754:	total: 1m 30s	remaining: 12.6s
# 1755:	total: 1m 30s	remaining: 12.6s
# 1756:	total: 1m 30s	remaining: 12.5s
# 1757:	total: 1m 30s	remaining: 12.5s
# 1758:	total: 1m 30s	remaining: 12.4s
# 1759:	total: 1m 30s	remaining: 12.4s
# 1760:	total: 1m 30s	remaining: 12.3s
# 1761:	total: 1m 30s	remaining: 12.3s
# 1762:	total: 1m 30s	remaining: 12.2s
# 1763:	total: 1m 30s	remaining: 12.2s
# 1764:	total: 1m 31s	remaining: 12.1s
# 1765:	total: 1m 31s	remaining: 12.1s
# 1766:	total: 1m 31s	remaining: 12s
# 1767:	total: 1m 31s	remaining: 12s
# 1768:	total: 1m 31s	remaining: 11.9s
# 1769:	total: 1m 31s	remaining: 11.9s
# 1770:	total: 1m 31s	remaining: 11.8s
# 1771:	total: 1m 31s	remaining: 11.8s
# 1772:	total: 1m 31s	remaining: 11.7s
# 1773:	total: 1m 31s	remaining: 11.6s
# 1774:	total: 1m 31s	remaining: 11.6s
# 1775:	total: 1m 31s	remaining: 11.5s
# 1776:	total: 1m 31s	remaining: 11.5s
# 1777:	total: 1m 31s	remaining: 11.4s
# 1778:	total: 1m 31s	remaining: 11.4s
# 1779:	total: 1m 31s	remaining: 11.3s
# 1780:	total: 1m 31s	remaining: 11.3s
# 1781:	total: 1m 31s	remaining: 11.2s
# 1782:	total: 1m 31s	remaining: 11.2s
# 1783:	total: 1m 31s	remaining: 11.1s
# 1784:	total: 1m 31s	remaining: 11.1s
# 1785:	total: 1m 31s	remaining: 11s
# 1786:	total: 1m 32s	remaining: 11s
# 1787:	total: 1m 32s	remaining: 10.9s
# 1788:	total: 1m 32s	remaining: 10.9s
# 1789:	total: 1m 32s	remaining: 10.8s
# 1790:	total: 1m 32s	remaining: 10.8s
# 1791:	total: 1m 32s	remaining: 10.7s
# 1792:	total: 1m 32s	remaining: 10.7s
# 1793:	total: 1m 32s	remaining: 10.6s
# 1794:	total: 1m 32s	remaining: 10.5s
# 1795:	total: 1m 32s	remaining: 10.5s
# 1796:	total: 1m 32s	remaining: 10.4s
# 1797:	total: 1m 32s	remaining: 10.4s
# 1798:	total: 1m 32s	remaining: 10.3s
# 1799:	total: 1m 32s	remaining: 10.3s
# 1800:	total: 1m 32s	remaining: 10.2s
# 1801:	total: 1m 32s	remaining: 10.2s
# 1802:	total: 1m 32s	remaining: 10.1s
# 1803:	total: 1m 32s	remaining: 10.1s
# 1804:	total: 1m 32s	remaining: 10s
# 1805:	total: 1m 32s	remaining: 9.97s
# 1806:	total: 1m 32s	remaining: 9.92s
# 1807:	total: 1m 32s	remaining: 9.87s
# 1808:	total: 1m 32s	remaining: 9.81s
# 1809:	total: 1m 33s	remaining: 9.76s
# 1810:	total: 1m 33s	remaining: 9.71s
# 1811:	total: 1m 33s	remaining: 9.66s
# 1812:	total: 1m 33s	remaining: 9.61s
# 1813:	total: 1m 33s	remaining: 9.55s
# 1814:	total: 1m 33s	remaining: 9.5s
# 1815:	total: 1m 33s	remaining: 9.45s
# 1816:	total: 1m 33s	remaining: 9.4s
# 1817:	total: 1m 33s	remaining: 9.35s
# 1818:	total: 1m 33s	remaining: 9.29s
# 1819:	total: 1m 33s	remaining: 9.24s
# 1820:	total: 1m 33s	remaining: 9.19s
# 1821:	total: 1m 33s	remaining: 9.14s
# 1822:	total: 1m 33s	remaining: 9.09s
# 1823:	total: 1m 33s	remaining: 9.03s
# 1824:	total: 1m 33s	remaining: 8.98s
# 1825:	total: 1m 33s	remaining: 8.93s
# 1826:	total: 1m 33s	remaining: 8.88s
# 1827:	total: 1m 33s	remaining: 8.82s
# 1828:	total: 1m 33s	remaining: 8.77s
# 1829:	total: 1m 33s	remaining: 8.72s
# 1830:	total: 1m 33s	remaining: 8.67s
# 1831:	total: 1m 33s	remaining: 8.62s
# 1832:	total: 1m 34s	remaining: 8.56s
# 1833:	total: 1m 34s	remaining: 8.51s
# 1834:	total: 1m 34s	remaining: 8.46s
# 1835:	total: 1m 34s	remaining: 8.41s
# 1836:	total: 1m 34s	remaining: 8.36s
# 1837:	total: 1m 34s	remaining: 8.3s
# 1838:	total: 1m 34s	remaining: 8.25s
# 1839:	total: 1m 34s	remaining: 8.2s
# 1840:	total: 1m 34s	remaining: 8.15s
# 1841:	total: 1m 34s	remaining: 8.1s
# 1842:	total: 1m 34s	remaining: 8.04s
# 1843:	total: 1m 34s	remaining: 7.99s
# 1844:	total: 1m 34s	remaining: 7.94s
# 1845:	total: 1m 34s	remaining: 7.89s
# 1846:	total: 1m 34s	remaining: 7.84s
# 1847:	total: 1m 34s	remaining: 7.79s
# 1848:	total: 1m 34s	remaining: 7.73s
# 1849:	total: 1m 34s	remaining: 7.68s
# 1850:	total: 1m 34s	remaining: 7.63s
# 1851:	total: 1m 34s	remaining: 7.58s
# 1852:	total: 1m 34s	remaining: 7.53s
# 1853:	total: 1m 34s	remaining: 7.47s
# 1854:	total: 1m 34s	remaining: 7.42s
# 1855:	total: 1m 35s	remaining: 7.37s
# 1856:	total: 1m 35s	remaining: 7.32s
# 1857:	total: 1m 35s	remaining: 7.27s
# 1858:	total: 1m 35s	remaining: 7.21s
# 1859:	total: 1m 35s	remaining: 7.16s
# 1860:	total: 1m 35s	remaining: 7.11s
# 1861:	total: 1m 35s	remaining: 7.06s
# 1862:	total: 1m 35s	remaining: 7.01s
# 1863:	total: 1m 35s	remaining: 6.96s
# 1864:	total: 1m 35s	remaining: 6.91s
# 1865:	total: 1m 35s	remaining: 6.85s
# 1866:	total: 1m 35s	remaining: 6.8s
# 1867:	total: 1m 35s	remaining: 6.75s
# 1868:	total: 1m 35s	remaining: 6.7s
# 1869:	total: 1m 35s	remaining: 6.65s
# 1870:	total: 1m 35s	remaining: 6.59s
# 1871:	total: 1m 35s	remaining: 6.54s
# 1872:	total: 1m 35s	remaining: 6.49s
# 1873:	total: 1m 35s	remaining: 6.45s
# 1874:	total: 1m 35s	remaining: 6.4s
# 1875:	total: 1m 36s	remaining: 6.35s
# 1876:	total: 1m 36s	remaining: 6.3s
# 1877:	total: 1m 36s	remaining: 6.25s
# 1878:	total: 1m 36s	remaining: 6.2s
# 1879:	total: 1m 36s	remaining: 6.15s
# 1880:	total: 1m 36s	remaining: 6.1s
# 1881:	total: 1m 36s	remaining: 6.05s
# 1882:	total: 1m 36s	remaining: 6s
# 1883:	total: 1m 36s	remaining: 5.95s
# 1884:	total: 1m 36s	remaining: 5.9s
# 1885:	total: 1m 36s	remaining: 5.85s
# 1886:	total: 1m 36s	remaining: 5.8s
# 1887:	total: 1m 37s	remaining: 5.76s
# 1888:	total: 1m 37s	remaining: 5.71s
# 1889:	total: 1m 37s	remaining: 5.66s
# 1890:	total: 1m 37s	remaining: 5.61s
# 1891:	total: 1m 37s	remaining: 5.56s
# 1892:	total: 1m 37s	remaining: 5.51s
# 1893:	total: 1m 37s	remaining: 5.46s
# 1894:	total: 1m 37s	remaining: 5.41s
# 1895:	total: 1m 37s	remaining: 5.36s
# 1896:	total: 1m 37s	remaining: 5.31s
# 1897:	total: 1m 37s	remaining: 5.26s
# 1898:	total: 1m 37s	remaining: 5.21s
# 1899:	total: 1m 38s	remaining: 5.16s
# 1900:	total: 1m 38s	remaining: 5.11s
# 1901:	total: 1m 38s	remaining: 5.06s
# 1902:	total: 1m 38s	remaining: 5.01s
# 1903:	total: 1m 38s	remaining: 4.96s
# 1904:	total: 1m 38s	remaining: 4.91s
# 1905:	total: 1m 38s	remaining: 4.86s
# 1906:	total: 1m 38s	remaining: 4.81s
# 1907:	total: 1m 38s	remaining: 4.76s
# 1908:	total: 1m 38s	remaining: 4.71s
# 1909:	total: 1m 38s	remaining: 4.66s
# 1910:	total: 1m 38s	remaining: 4.61s
# 1911:	total: 1m 39s	remaining: 4.56s
# 1912:	total: 1m 39s	remaining: 4.51s
# 1913:	total: 1m 39s	remaining: 4.46s
# 1914:	total: 1m 39s	remaining: 4.41s
# 1915:	total: 1m 39s	remaining: 4.36s
# 1916:	total: 1m 39s	remaining: 4.31s
# 1917:	total: 1m 39s	remaining: 4.26s
# 1918:	total: 1m 39s	remaining: 4.21s
# 1919:	total: 1m 39s	remaining: 4.16s
# 1920:	total: 1m 39s	remaining: 4.11s
# 1921:	total: 1m 39s	remaining: 4.05s
# 1922:	total: 1m 40s	remaining: 4s
# 1923:	total: 1m 40s	remaining: 3.96s
# 1924:	total: 1m 40s	remaining: 3.9s
# 1925:	total: 1m 40s	remaining: 3.85s
# 1926:	total: 1m 40s	remaining: 3.8s
# 1927:	total: 1m 40s	remaining: 3.75s
# 1928:	total: 1m 40s	remaining: 3.69s
# 1929:	total: 1m 40s	remaining: 3.64s
# 1930:	total: 1m 40s	remaining: 3.59s
# 1931:	total: 1m 40s	remaining: 3.54s
# 1932:	total: 1m 40s	remaining: 3.48s
# 1933:	total: 1m 40s	remaining: 3.43s
# 1934:	total: 1m 40s	remaining: 3.38s
# 1935:	total: 1m 40s	remaining: 3.33s
# 1936:	total: 1m 40s	remaining: 3.28s
# 1937:	total: 1m 40s	remaining: 3.22s
# 1938:	total: 1m 40s	remaining: 3.17s
# 1939:	total: 1m 40s	remaining: 3.12s
# 1940:	total: 1m 40s	remaining: 3.07s
# 1941:	total: 1m 40s	remaining: 3.01s
# 1942:	total: 1m 40s	remaining: 2.96s
# 1943:	total: 1m 41s	remaining: 2.91s
# 1944:	total: 1m 41s	remaining: 2.86s
# 1945:	total: 1m 41s	remaining: 2.81s
# 1946:	total: 1m 41s	remaining: 2.75s
# 1947:	total: 1m 41s	remaining: 2.7s
# 1948:	total: 1m 41s	remaining: 2.65s
# 1949:	total: 1m 41s	remaining: 2.6s
# 1950:	total: 1m 41s	remaining: 2.54s
# 1951:	total: 1m 41s	remaining: 2.49s
# 1952:	total: 1m 41s	remaining: 2.44s
# 1953:	total: 1m 41s	remaining: 2.39s
# 1954:	total: 1m 41s	remaining: 2.34s
# 1955:	total: 1m 41s	remaining: 2.28s
# 1956:	total: 1m 41s	remaining: 2.23s
# 1957:	total: 1m 41s	remaining: 2.18s
# 1958:	total: 1m 41s	remaining: 2.13s
# 1959:	total: 1m 41s	remaining: 2.08s
# 1960:	total: 1m 41s	remaining: 2.02s
# 1961:	total: 1m 41s	remaining: 1.97s
# 1962:	total: 1m 41s	remaining: 1.92s
# 1963:	total: 1m 41s	remaining: 1.87s
# 1964:	total: 1m 41s	remaining: 1.82s
# 1965:	total: 1m 42s	remaining: 1.76s
# 1966:	total: 1m 42s	remaining: 1.71s
# 1967:	total: 1m 42s	remaining: 1.66s
# 1968:	total: 1m 42s	remaining: 1.61s
# 1969:	total: 1m 42s	remaining: 1.56s
# 1970:	total: 1m 42s	remaining: 1.5s
# 1971:	total: 1m 42s	remaining: 1.45s
# 1972:	total: 1m 42s	remaining: 1.4s
# 1973:	total: 1m 42s	remaining: 1.35s
# 1974:	total: 1m 42s	remaining: 1.3s
# 1975:	total: 1m 42s	remaining: 1.24s
# 1976:	total: 1m 42s	remaining: 1.19s
# 1977:	total: 1m 42s	remaining: 1.14s
# 1978:	total: 1m 42s	remaining: 1.09s
# 1979:	total: 1m 42s	remaining: 1.04s
# 1980:	total: 1m 42s	remaining: 985ms
# 1981:	total: 1m 42s	remaining: 934ms
# 1982:	total: 1m 42s	remaining: 882ms
# 1983:	total: 1m 43s	remaining: 831ms
# 1984:	total: 1m 43s	remaining: 780ms
# 1985:	total: 1m 43s	remaining: 728ms
# 1986:	total: 1m 43s	remaining: 677ms
# 1987:	total: 1m 43s	remaining: 625ms
# 1988:	total: 1m 43s	remaining: 573ms
# 1989:	total: 1m 43s	remaining: 521ms
# 1990:	total: 1m 43s	remaining: 468ms
# 1991:	total: 1m 43s	remaining: 416ms
# 1992:	total: 1m 43s	remaining: 364ms
# 1993:	total: 1m 43s	remaining: 312ms
# 1994:	total: 1m 43s	remaining: 260ms
# 1995:	total: 1m 43s	remaining: 208ms
# 1996:	total: 1m 43s	remaining: 156ms
# 1997:	total: 1m 43s	remaining: 104ms
# 1998:	total: 1m 43s	remaining: 52ms
# 1999:	total: 1m 44s	remaining: 0us

# %%
y_pred = cat.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[21535  1182]
#  [ 2796  3579]]
# 0.8632613776983363
#               precision    recall  f1-score   support
#
#        False       0.89      0.95      0.92     22717
#         True       0.75      0.56      0.64      6375
#
#     accuracy                           0.86     29092
#    macro avg       0.82      0.75      0.78     29092
# weighted avg       0.86      0.86      0.86     29092

# %%
from sklearn.metrics import roc_auc_score

# Assuming `y_pred` is the predicted labels
y_pred = cat.predict(X_test)
auc_score = roc_auc_score(y_test, y_pred)
print(f"AUC Score: {auc_score}")
# Out:
# AUC Score: 0.7546901232298174

# %%
rf=RandomForestClassifier()
rf.fit(X_train_res,y_train_res)
# Out:
# RandomForestClassifier()

# %%
# Make sure X_test only contains columns present in X_train
X_test = pd.DataFrame(X_test, columns=X_train.columns)
X_test = X_test[X_train.columns]  # Align the columns to match X_train

# %%
y_pred1 = rf.predict(X_test)  # Predict the target variable (y) for the test data (X_test)
print(confusion_matrix(y_test, y_pred1))  # Confusion matrix to evaluate the performance
print(accuracy_score(y_test, y_pred1))  # Accuracy score
print(classification_report(y_test, y_pred1))  # Precision, recall, F1-score for each class
# Out:
# [[22717     0]
#  [ 6375     0]]
# 0.7808675924652826
#               precision    recall  f1-score   support
#
#        False       0.78      1.00      0.88     22717
#         True       0.00      0.00      0.00      6375
#
#     accuracy                           0.78     29092
#    macro avg       0.39      0.50      0.44     29092
# weighted avg       0.61      0.78      0.68     29092
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.metrics import roc_auc_score

# Assuming `y_pred` is the predicted labels
y_pred = rf.predict(X_test)
auc_score = roc_auc_score(y_test, y_pred)
print(f"AUC Score: {auc_score}")
# Out:
# AUC Score: 0.5

# %%
logreg = LogisticRegression()
logreg.fit(X_train_res, y_train_res)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Make sure X_test only contains columns present in X_train
X_test = pd.DataFrame(X_test, columns=X_train.columns)
X_test = X_test[X_train.columns]  # Align the columns to match X_train

# %%
import pandas as pd

print(X_test.isnull().sum())  # Check missing values per column
print(X_test.isnull().sum().sum())  # Check total missing values
# Out:
# 0     29092
# 1     29092
# 2     29092
# 3     29092
# 4     29092
# 5     29092
# 6     29092
# 7     29092
# 8     29092
# 9     29092
# 10    29092
# 11    29092
# 12    29092
# 13    29092
# 14    29092
# 15    29092
# 16    29092
# 17    29092
# 18    29092
# 19    29092
# 20    29092
# dtype: int64
# 610932

# %%
y_pred2 = logreg.predict(X_test)  # Predict the target variable (y) for the test data (X_test)
print(confusion_matrix(y_test, y_pred2))  # Confusion matrix to evaluate the performance
print(accuracy_score(y_test, y_pred2))  # Accuracy score
print(classification_report(y_test, y_pred2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-116-9c8a34d0f4ee> in <cell line: 0>()
# ----> 1 y_pred2 = logreg.predict(X_test)  # Predict the target variable (y) for the test data (X_test)
#       2 print(confusion_matrix(y_test, y_pred2))  # Confusion matrix to evaluate the performance
#       3 print(accuracy_score(y_test, y_pred2))  # Accuracy score
#       4 print(classification_report(y_test, y_pred2))
#
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     372         """
#     373         xp, _ = get_namespace(X)
# --> 374         scores = self.decision_function(X)
#     375         if len(scores.shape) == 1:
#     376             indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     349         xp, _ = get_namespace(X)
#     350
# --> 351         X = validate_data(self, X, accept_sparse="csr", reset=False)
#     352         scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     353         return (
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2942             out = X, y
#    2943     elif not no_val_X and no_val_y:
# -> 2944         out = check_array(X, input_name="X", **check_params)
#    2945     elif no_val_X and not no_val_y:
#    2946         out = _check_y(y, **check_params)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1105
#    1106         if ensure_all_finite:
# -> 1107             _assert_all_finite(
#    1108                 array,
#    1109                 input_name=input_name,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     118         return
#     119
# --> 120     _assert_all_finite_element_wise(
#     121         X,
#     122         xp=xp,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     167                 "#estimators-that-handle-nan-values"
#     168             )
# --> 169         raise ValueError(msg_err)
#     170
#     171
#
# ValueError: Input X contains NaN.
# LogisticRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
from sklearn.metrics import roc_auc_score

# Assuming `y_pred` is the predicted labels
y_pred = .predict(X_test)
auc_score = roc_auc_score(y_test, y_pred,average= None)
print(f"AUC Score: {auc_score}")
# Out:
# AUC Score: 0.5

# %%
gnb = GaussianNB()
gnb.fit(X_train_res, y_train_res)
# Out:
# GaussianNB()

# %%
y_pred3 = gnb.predict(X_test)
print(confusion_matrix(y_test,y_pred3))
print(accuracy_score(y_test,y_pred3))
print(classification_report(y_test,y_pred3))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-119-67503cc46dcd> in <cell line: 0>()
# ----> 1 y_pred3 = gnb.predict(X_test)
#       2 print(confusion_matrix(y_test,y_pred3))
#       3 print(accuracy_score(y_test,y_pred3))
#       4 print(classification_report(y_test,y_pred3))
#
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py in predict(self, X)
#     103         """
#     104         check_is_fitted(self)
# --> 105         X = self._check_X(X)
#     106         jll = self._joint_log_likelihood(X)
#     107         return self.classes_[np.argmax(jll, axis=1)]
#
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py in _check_X(self, X)
#     270     def _check_X(self, X):
#     271         """Validate X, used only in predict* methods."""
# --> 272         return validate_data(self, X, reset=False)
#     273
#     274     @staticmethod
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2942             out = X, y
#    2943     elif not no_val_X and no_val_y:
# -> 2944         out = check_array(X, input_name="X", **check_params)
#    2945     elif no_val_X and not no_val_y:
#    2946         out = _check_y(y, **check_params)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1105
#    1106         if ensure_all_finite:
# -> 1107             _assert_all_finite(
#    1108                 array,
#    1109                 input_name=input_name,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     118         return
#     119
# --> 120     _assert_all_finite_element_wise(
#     121         X,
#     122         xp=xp,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     167                 "#estimators-that-handle-nan-values"
#     168             )
# --> 169         raise ValueError(msg_err)
#     170
#     171
#
# ValueError: Input X contains NaN.
# GaussianNB does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
metrics.plot_roc_curve(gnb, X_test, y_test)
metrics.roc_auc_score(y_test, y_pred3, average=None)
# Out:
# 0.7456113906230715

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train_res, y_train_res)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred4 = knn.predict(X_test)
print(confusion_matrix(y_test,y_pred4))
print(accuracy_score(y_test,y_pred4))
print(classification_report(y_test,y_pred4))
# Out:
# [[17306  5411]
#  [ 1771  4604]]
# 0.7531280076997112
#               precision    recall  f1-score   support
#
#            0       0.91      0.76      0.83     22717
#            1       0.46      0.72      0.56      6375
#
#     accuracy                           0.75     29092
#    macro avg       0.68      0.74      0.69     29092
# weighted avg       0.81      0.75      0.77     29092

# %%
metrics.plot_roc_curve(knn, X_test, y_test)
metrics.roc_auc_score(y_test, y_pred4, average=None)
# Out:
# 0.7420022078999315

# %%
xgb = XGBClassifier()
xgb.fit(X_train_res, y_train_res)
# Out:
# c:\users\admin\anaconda3\envs\rainprediction\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [09:09:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=8, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pred6 = xgb.predict(X_test)
print(confusion_matrix(y_test,y_pred6))
print(accuracy_score(y_test,y_pred6))
print(classification_report(y_test,y_pred6))
# Out:
# [[21396  1321]
#  [ 2844  3531]]
# 0.8568334937439847
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91     22717
#            1       0.73      0.55      0.63      6375
#
#     accuracy                           0.86     29092
#    macro avg       0.81      0.75      0.77     29092
# weighted avg       0.85      0.86      0.85     29092

# %%
metrics.plot_roc_curve(xgb, X_test, y_test)
metrics.roc_auc_score(y_test, y_pred6, average=None)
# Out:
# 0.7478660345064204

# %%
svc = SVC()
svc.fit(X_train_res, y_train_res)
# Out:
# SVC()

# %%
y_pred5 = svc.predict(X_test)
print(confusion_matrix(y_test,y_pred5))
print(accuracy_score(y_test,y_pred5))
print(classification_report(y_test,y_pred5))
# Out:
# [[17824  4893]
#  [ 1594  4781]]
# 0.7770177368348687
#               precision    recall  f1-score   support
#
#            0       0.92      0.78      0.85     22717
#            1       0.49      0.75      0.60      6375
#
#     accuracy                           0.78     29092
#    macro avg       0.71      0.77      0.72     29092
# weighted avg       0.83      0.78      0.79     29092

# %%
metrics.plot_roc_curve(svc, X_test, y_test)
metrics.roc_auc_score(y_test, y_pred5, average=None)
# Out:
# 0.7672857141624093

# %%
# joblib.dump(rf, "rf.pkl")
# joblib.dump(cat, "cat.pkl")
# joblib.dump(logreg, "logreg.pkl")
# joblib.dump(gnb, "gnb.pkl")
# joblib.dump(knn, "knn.pkl")
joblib.dump(svc, "svc.pkl")
joblib.dump(xgb, "xgb.pkl")
# Out:
# ['xgb.pkl']
